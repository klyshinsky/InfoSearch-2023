# %% [markdown]
# <h2><center>Методы анализа текстов</center></h2>

# %% [markdown]
# ### Этапы анализа текстов
#
# При обработке текстов выделяют несколько этапов анализа.
# * Токенизация (графематический анализ) - выделение абзацев, предложений, токенов. Если абзацы в HTML выделяются довольно просто - по тегам &lt;p&gt;, то с выделением предложений и слов могут быть проблемы.
# `Г. Мурманск был основан 3 апреля 1915 г. ниже впадения р. Туломы в Кольский залив. Минимальные IP-адреса: 109.124.97.0 - 109.124.97.3.`
# * Морфологический анализ (стемминг, лемматизация) - определение начальной формы слова или его псевдопрефикса, грамматических параметров. Подробнее описан ниже.
# * Синтаксический анализ - определение связей между словами (деревья зависимостей) или синтаксически связанных групп слов (деревья составляющих). Первые больше подходят для русского языка, вторые - для английского.
#
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/0/0d/Wearetryingtounderstandthedifference_%282%29.jpg">
#     <a href="https://en.wikipedia.org/wiki/Dependency_grammar">Деревья зависимостей</a>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Competing_sentence_diagrams.png/750px-Competing_sentence_diagrams.png">
# <a href="https://en.wikipedia.org/wiki/Constituent_(linguistics)">Деревья составляющих</a></center>
#
# * Семантический анализ - определение смысла слова и работа с ним (`за'мок` vs `замо'к`, `удаление ребра связанного графа`; не путать с `он видел их семью своими глазами` где имеет место грамматическая неоднозначность `семья`-`семь`). Последнее время чаще используются дистрибутивные модели языка, о которых мы поговорим на отдельном занятии.
#
# Задачей морфологического анализа является определение начальной формы слова, его части речи и грамматических параметров. В некоторых случаях от слова требуется только начальная форма, в других - только начальная форма и часть речи.<br>
# Существует два больших подхода к морфологическому анализу: <b>стемминг</b> и <b>поиск по словарю</b>. Для проведения стемминга оставляется справочник всех окончаний для данного языка. Для пришедшего слова проверяется его окончание и по нему делается прогноз начальной формы и части речи.<br>
# Например, мы создаем справочник, в котором записываем все окончания прилагательных: <i>-ому, -ему, -ой, -ая, -ий, -ый, ...</i> Теперь все слова, которые имеют такое окончание будут считаться прилагаельными: <i>синий, циклический, красного, больному</i>. Заодно прилагательными будут считаться причастия (<i>делающий, строившему</i>) и местоимения (<i>мой, твой, твоему</i>). Также не понятно что делать со словами, имеющими пустое окончание. Отдельную проблему составляют такие слова, как <i>стекло, больной, вина</i>, которые могут разбираться несколькими вариантами (это явление называется <b>омонимией</b>). Помимо этого, стеммер может просто откусывать окончания, оставляя лишь псевдооснову.<br>
# Большинство проблем здесь решается, но точность работы бессловарных стеммеров находится на уровне 80%. Чтобы повысить точность испольуют морфологический анализ со словарем. Разработчики составляют словарь слов, встретившихся в текстах (<a href="http://opencorpora.org/dict.php">здесь</a> можно найти пример такого словаря). Теперь каждое слово будет искаться в словаре и не предсказываться, а выдаваться точно. Для слов, отсутствующих в словаре, может применяться предсказание, пообное работе стеммера.<br>

# %% [markdown]
# ## Морфологический анализ
#
# Есть несколько наиболее распространенных библиотеки для морфологического анализа текстов на Python: pymorphy2, pymystem и nltk. Рассмотрим работу с ними.
#
# Библиотеки pymorphy основана на словаре [OpenCorpora](opencorpora.org/) и позволяет проводить анализ отдельных слов, то есть предварительно необходимо провести графематический анализ.

# %%
import pymorphy2 # Морфологический анализатор.

# %% [markdown]
# Посмотрим на результаты анализа отдельного слова.

# %%
morph=pymorphy2.MorphAnalyzer() # Создает объект морфоанализатора и загружет словарь.
wordform=morph.parse('стекло')  # Проведем анализ слова "стекло"...
print(wordform)                 # ... и посмотрим на результат.
# Out:
# [Parse(word='стекло', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='стекло', score=0.690476, methods_stack=((DictionaryAnalyzer(), 'стекло', 157, 0),)), Parse(word='стекло', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='стекло', score=0.285714, methods_stack=((DictionaryAnalyzer(), 'стекло', 157, 3),)), Parse(word='стекло', tag=OpencorporaTag('VERB,perf,intr neut,sing,past,indc'), normal_form='стечь', score=0.023809, methods_stack=((DictionaryAnalyzer(), 'стекло', 1015, 3),))]

# %% [markdown]
# Как видно из вывода, слово "стекло" может быть неодушевленным существительным среднего рода, единственного числа, именительного падежа `tag=OpencorporaTag('NOUN,inan,neut sing,nomn')`, аналогично, но в винительном падеже (`'NOUN,inan,neut sing,accs'`), и глаголом `'VERB,perf,intr neut,sing,past,indc'`. При этом в первой форме оно встречается в 75% случаев (<i>score=0.75</i>), во второй в 18,75% случаев (<i>score=0.1875</i>), а как глагол - лишь в 6,25% (<i>score=0.0625</i>). Самым простым видом борьбы с омонимией является выбор нулевого элемента из списка, возвращенного морфологическим анализом. Такой подход дает около 90% точности при выборе начальной формы и до 80% если мы обращаем внимание на грамматические параметры.

# %%
wordform[0].score
# Out:
# 0.690476

# %%
wordform[0].tag
# Out:
# OpencorporaTag('NOUN,inan,neut sing,nomn')

# %% [markdown]
# Pymorphy2 умеет синтезировать нужные нам формы слова. Для этого необходимо получить объект типа `Parse` для нужного слова, а затем вызвать функцию `inflect`.

# %%
wordform[0].inflect({'plur','datv'})
# Out:
# Parse(word='стёклам', tag=OpencorporaTag('NOUN,inan,neut plur,datv'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёклам', 157, 8),))

# %% [markdown]
# Помимо этого можно получить вообще всю лексему.

# %%
wordform[0].lexeme
# Out:
# [Parse(word='стекло', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стекло', 157, 0),)),
#  Parse(word='стекла', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стекла', 157, 1),)),
#  Parse(word='стеклу', tag=OpencorporaTag('NOUN,inan,neut sing,datv'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стеклу', 157, 2),)),
#  Parse(word='стекло', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стекло', 157, 3),)),
#  Parse(word='стеклом', tag=OpencorporaTag('NOUN,inan,neut sing,ablt'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стеклом', 157, 4),)),
#  Parse(word='стекле', tag=OpencorporaTag('NOUN,inan,neut sing,loct'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стекле', 157, 5),)),
#  Parse(word='стёкла', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёкла', 157, 6),)),
#  Parse(word='стёкол', tag=OpencorporaTag('NOUN,inan,neut plur,gent'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёкол', 157, 7),)),
#  Parse(word='стёклам', tag=OpencorporaTag('NOUN,inan,neut plur,datv'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёклам', 157, 8),)),
#  Parse(word='стёкла', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёкла', 157, 9),)),
#  Parse(word='стёклами', tag=OpencorporaTag('NOUN,inan,neut plur,ablt'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёклами', 157, 10),)),
#  Parse(word='стёклах', tag=OpencorporaTag('NOUN,inan,neut plur,loct'), normal_form='стекло', score=1.0, methods_stack=((DictionaryAnalyzer(), 'стёклах', 157, 11),))]

# %% [markdown]
# Обратите внимание на `methods_stack=((<DictionaryAnalyzer>, 'лось', 121, 0)` и `methods_stack=((<FakeDictionary>, 'варкалось', 224, 9)`. Наличие строки <FakeDictionary> говорито том, что слово было предсказано. Причем в первом случае оно предсказано как форма слова _лось_, к которому добавлена неизвестная приставка. Во втором случае - это совершенно незнакомое слово.

# %% [markdown]
# А ещё pymorphy умеет предсказывать незнакомые слова.

# %%
wordform=morph.parse('пырялись') 
wordform
# Out:
# [Parse(word='пырялись', tag=OpencorporaTag('VERB,impf,intr plur,past,indc'), normal_form='пыряться', score=1.0, methods_stack=((FakeDictionary(), 'пырялись', 234, 10), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'ялись')))]

# %% [markdown]
# Вместо Pymorphy можно использовать PyMystem. Его плюсом является тот факт, что он сам проводит графематический анализ и снимает омонимию.
#
# Функция `lemmatize` делит текст на слова и знаки препинания, а затем возвращает для них только начальную форму.
#
# Функция `analyze` возвращает не только начальную форму, но и всю информацию о слове, как это делал перед этим Pymorphy.
#
# Как видно из примера, делает он это не всегда корректно, но нам не придется думать о том, какое вариант разбора следует взять.

# %%
import pymystem3 # Еще один морфологический анализатор. При первом запуске грузит словари из Сети.

# %%
mystem=pymystem3.Mystem()
print(mystem.lemmatize('эти типы стали есть в цеху.'))
print(mystem.analyze('эти типы стали есть в цеху.'))
# Out:
# ['этот', ' ', 'тип', ' ', 'становиться', ' ', 'есть', ' ', 'в', ' ', 'цех', '.', '\n']
# [{'analysis': [{'lex': 'этот', 'wt': 1, 'gr': 'APRO=(им,мн|вин,мн,неод)'}], 'text': 'эти'}, {'text': ' '}, {'analysis': [{'lex': 'тип', 'wt': 0.8700298642, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'типы'}, {'text': ' '}, {'analysis': [{'lex': 'становиться', 'wt': 0.9821285244, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'стали'}, {'text': ' '}, {'analysis': [{'lex': 'есть', 'wt': 0.0492236161, 'gr': 'V,несов,пе=инф'}], 'text': 'есть'}, {'text': ' '}, {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'}, {'text': ' '}, {'analysis': [{'lex': 'цех', 'wt': 1, 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}], 'text': 'цеху'}, {'text': '.'}, {'text': '\n'}]

# %% [markdown]
# Результаты работы можно представить в таком виде.
#
# ```
# ['этот',
#  ' ',
#  'тип',
#  ' ',
#  'становиться',
#  ' ',
#  'есть',
#  ' ',
#  'в',
#  ' ',
#  'цех',
#  '.',
#  '\n']```
#
# ```
# [
#   {'analysis':
#     [{'lex': 'этот', 'wt': 1, 'gr': 'APRO=(им,мн|вин,мн,неод)'}],
#    'text': 'эти'
#   },
#   {
#     'text': ' '
#   },
#   {'analysis':
#     [{'lex': 'тип', 'wt': 0.8700298667, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#    'text': 'типы'},
#   {'text': ' '},
#   {'analysis':
#     [{'lex': 'становиться', 'wt': 0.9821285009, 'gr': 'V,нп=прош,мн,изъяв,сов'}],
#    'text': 'стали'},
#   {'text': ' '},
#   {'analysis':
#     [{'lex': 'есть', 'wt': 0.04922361672, 'gr': 'V,несов,пе=инф'}],
#    'text': 'есть'},
#   {'text': ' '},
#   {'analysis':
#     [{'lex': 'в', 'wt': 0.9999917746, 'gr': 'PR='}],
#    'text': 'в'},
#   {'text': ' '},
#   {'analysis':
#     [{'lex': 'цех', 'wt': 1, 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}],
#    'text': 'цеху'},
#   {'text': '.'},
#   {'text': '\n'}
# ]
# ```

# %% [markdown]
# То есть результатом является список токенов (в том числе и пробельных или знаков препинания), для части из которых имеется результат анализа, который хранится в словаре с ключём `analysis`. Анализ хранит в списке один или несколько вариантов разбора, у каждого из которых есть лемма `lex`, набор грамматических параметров `gr` и некоторый вес `wt`, который показывает степень уверенности системы в правильности ответа.

# %%
my_res=mystem.analyze('эти типы стали есть в цеху.')
if 'analysis' in my_res[0].keys(): # Проверяем, что это не разделитель.
    print(my_res[0]['analysis'][0]['gr'].split("=")[0]) # Берем из него анализ, из того грамматическсие параметы, 
                                                        # а из них выделяем часть речи.
# Out:
# APRO

# %% [markdown]
# Еще одна библиотека - NLTK. По сравнению с двумя предыдущими библиотеками она обладает более широкой функциональностью и изначально писалась для работы с разными языками.

# %%
import nltk # Иностранный морфологический анализатор.

# %% [markdown]
# Перед началом использования необходимо загрузить необходимые библиотеки или корпуса.

# %%
nltk.download() # По дороге будут появляться поле ввода. Грузит всё из Сети.
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> l
#
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [*] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [*] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue: l
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] extended_omw........ Extended Open Multilingual WordNet
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
# Hit Enter to continue: q
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# Можно сразу скачать нужный пакет, если вы знаете как он назыввается.

# %%
nltk.download(['averaged_perceptron_tagger_ru', 'stopwords'])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /home/edward/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /home/edward/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Функция `word_tokenize` возвращает начальные формы слов.
#
# Функция `pos_tag` возвращает список начальных форм и их частей речи.

# %%
tokens = nltk.word_tokenize('Эти типы стали есть в цеху') # Токенизация.
bi_tokens = list(nltk.bigrams(tokens))
tokens, bi_tokens
# Out:
# (['Эти', 'типы', 'стали', 'есть', 'в', 'цеху'],
#  [('Эти', 'типы'),
#   ('типы', 'стали'),
#   ('стали', 'есть'),
#   ('есть', 'в'),
#   ('в', 'цеху')])

# %%
pos = nltk.pos_tag(tokens) # Частеречная разметка.
bi_pos = list(nltk.bigrams(pos))
pos, bi_pos
# Out:
# ([('Эти', 'JJ'),
#   ('типы', 'NNP'),
#   ('стали', 'NNP'),
#   ('есть', 'NNP'),
#   ('в', 'NNP'),
#   ('цеху', 'NN')],
#  [(('Эти', 'JJ'), ('типы', 'NNP')),
#   (('типы', 'NNP'), ('стали', 'NNP')),
#   (('стали', 'NNP'), ('есть', 'NNP')),
#   (('есть', 'NNP'), ('в', 'NNP')),
#   (('в', 'NNP'), ('цеху', 'NN'))])

# %% [markdown]
# У NLTK заведен список стоп-слов, которые лучше фильтровать при анализе текстов. Но их не очень много. Зато самые мешающиеся.

# %%
# Оставим только те слова, которых нет в списке стоп-слов.
filtered_words = [token for token in tokens if token not in nltk.corpus.stopwords.words('russian')]
print('всего русских стоп-слов', len(nltk.corpus.stopwords.words('russian')))
filtered_words
# Out:
# всего русских стоп-слов 151
# ['Эти', 'типы', 'стали', 'цеху']

# %% [markdown]
# Ту же самую задачу в других библиотеках можно решить при помощи фильтра частей речи. Можно считать, что значимыми являются лишь существительные, прилагательные, глаголы, причастия и деепричастия. Ниже приведены названия частей речи для разных библиотек.
# <table>
# <tr><th>Часть речи</th><th>Pymorphy</th><th>Mystem</th><th>NLTK</th></tr>
# <tr><td>Существительное</td><td>NOUN</td><td>S</td><td>NN</td></tr>
# <tr><td>Прилагательное</td><td>ADJF, ADJS</td><td>A</td><td>NNP</td></tr>
# <tr><td>Глагол</td><td>VERB</td><td>V</td><td>JJ</td></tr>
# <tr><td>Причастие</td><td>PRTF, PRTS</td><td>V</td><td>NNP</td></tr>
# <tr><td>Деепричастие</td><td>GRND</td><td>V</td><td>NNP</td></tr>
# </table>

# %% [markdown]
# Возьмем новость с сайта Лента.ру и приведем все слова её текста к начальным формам при помощи разных библиотек. Прибавим при этом к словам части речи.

# %%
import re

# %%
text = """
Марсоход «Кьюриосити» отыскал одно из лучших свидетельств существования жидкой воды в кратере Гейл в далеком прошлом Марса. Ровер обнаружил на скалах волнообразную текстуру, которая сформировалась, когда скалы были дном неглубокого озера, сообщается на сайте NASA.\n
«Кьюриосити» работает на Марсе более десяти лет, преодолев за это время почти 30 километров. Основной целью ровера стала пятикилометровая гора Шарпа, расположенная в центре кратера Гейл и покрытая массивом из эродированных слоев осадочных пород. Там он проводит геологические исследования и изучает атмосферу Красной планеты.\n
Восьмого февраля 2023 года команда ровера сообщила, что обнаружила одно из лучших свидетельств существования жидкой воды в кратере за все время работы «Кьюриосити». Поднявшись почти на 800 метров над основанием горы Шарп ровер попал в область, названную «Долиной маркерной полосы» (Marker Band Valley) — тонком слое темных скал, который выделяется на фоне остальной части горы. Породы здесь очень твердые, и ранее ровер не смог получить их образец, хотя сделал несколько попыток.
"""

# %%
# Pymorphy
def normalizePymorphy(text):
    tokens = re.findall('[A-Za-zА-Яа-яЁё]+\-[A-Za-zА-Яа-яЁё]+|[A-Za-zА-Яа-яЁё]+', text)
    words = []
    for t in tokens:
        pv = morph.parse(t)
        words.append(pv[0].normal_form + '_' + str(pv[0].tag.POS)) # Берем наиболее вероятную форму.
    return words    
        
# Обратите внимание, что про иностранные слова словарь ничего не знает.
normalizePymorphy(text)
# Out:
# ['марсоход_NOUN',
#  'кьюриосити_NOUN',
#  'отыскать_VERB',
#  'один_ADJF',
#  'из_PREP',
#  'хороший_ADJF',
#  'свидетельство_NOUN',
#  'существование_NOUN',
#  'жидкий_ADJF',
#  'вода_NOUN',
#  'в_PREP',
#  'кратер_NOUN',
#  'гейл_NOUN',
#  'в_PREP',
#  'далёкий_ADJF',
#  'прошлый_ADJF',
#  'марс_NOUN',
#  'ровер_NOUN',
#  'обнаружить_VERB',
#  'на_PREP',
#  'скала_NOUN',
#  'волнообразный_ADJF',
#  'текстура_NOUN',
#  'который_ADJF',
#  'сформироваться_VERB',
#  'когда_CONJ',
#  'скала_NOUN',
#  'быть_VERB',
#  'дно_NOUN',
#  'неглубокий_ADJF',
#  'озеро_NOUN',
#  'сообщаться_VERB',
#  'на_PREP',
#  'сайт_NOUN',
#  'nasa_None',
#  'кьюриосити_NOUN',
#  'работать_VERB',
#  'на_PREP',
#  'марс_NOUN',
#  'более_ADVB',
#  'десять_NUMR',
#  'год_NOUN',
#  'преодолеть_GRND',
#  'за_PREP',
#  'это_PRCL',
#  'время_NOUN',
#  'почти_ADVB',
#  'километр_NOUN',
#  'основной_ADJF',
#  'цель_NOUN',
#  'ровер_NOUN',
#  'стать_VERB',
#  'пятикилометровый_ADJF',
#  'гора_NOUN',
#  'шарп_NOUN',
#  'расположить_PRTF',
#  'в_PREP',
#  'центр_NOUN',
#  'кратер_NOUN',
#  'гейл_NOUN',
#  'и_CONJ',
#  'покрыть_PRTF',
#  'массив_NOUN',
#  'из_PREP',
#  'эродировать_PRTF',
#  'слой_NOUN',
#  'осадочный_ADJF',
#  'порода_NOUN',
#  'там_ADVB',
#  'он_NPRO',
#  'проводить_VERB',
#  'геологический_ADJF',
#  'исследование_NOUN',
#  'и_CONJ',
#  'изучать_VERB',
#  'атмосфера_NOUN',
#  'красный_ADJF',
#  'планета_NOUN',
#  'восьмой_ADJF',
#  'февраль_NOUN',
#  'год_NOUN',
#  'команда_NOUN',
#  'ровер_NOUN',
#  'сообщить_VERB',
#  'что_CONJ',
#  'обнаружить_VERB',
#  'один_ADJF',
#  'из_PREP',
#  'хороший_ADJF',
#  'свидетельство_NOUN',
#  'существование_NOUN',
#  'жидкий_ADJF',
#  'вода_NOUN',
#  'в_PREP',
#  'кратер_NOUN',
#  'за_PREP',
#  'всё_PRCL',
#  'время_NOUN',
#  'работа_NOUN',
#  'кьюриосити_NOUN',
#  'подняться_GRND',
#  'почти_ADVB',
#  'на_PREP',
#  'метр_NOUN',
#  'над_PREP',
#  'основание_NOUN',
#  'гора_NOUN',
#  'шарп_NOUN',
#  'ровер_NOUN',
#  'попасть_VERB',
#  'в_PREP',
#  'область_NOUN',
#  'назвать_PRTF',
#  'долина_NOUN',
#  'маркерный_ADJF',
#  'полоса_NOUN',
#  'marker_None',
#  'band_None',
#  'valley_None',
#  'тонкий_ADJF',
#  'слой_NOUN',
#  'тёмный_ADJF',
#  'скала_NOUN',
#  'который_ADJF',
#  'выделяться_VERB',
#  'на_PREP',
#  'фон_NOUN',
#  'остальной_ADJF',
#  'часть_NOUN',
#  'гора_NOUN',
#  'порода_NOUN',
#  'здесь_ADVB',
#  'очень_ADVB',
#  'твёрдый_ADJF',
#  'и_CONJ',
#  'ранее_ADVB',
#  'ровер_NOUN',
#  'не_PRCL',
#  'смочь_VERB',
#  'получить_INFN',
#  'они_NPRO',
#  'образец_NOUN',
#  'хотя_CONJ',
#  'сделать_VERB',
#  'несколько_ADVB',
#  'попытка_NOUN']

# %%
# PyMystem
def normalizePymystem(text):
    tokens = mystem.analyze(text)
    words = []
    for t in tokens:
        if 'analysis' in t.keys():
            if t['analysis'] != []:
                words.append(t['analysis'][0]['lex']+'_'+t['analysis'][0]['gr'][0])
            else:
                words.append(t['text']+'_'+'U')
    return words    
        
# Не все считают, что причастие всегда выступает в роли глагола, но иногда так значительно проще.
normalizePymystem(text)
# Out:
# ['марсоход_S',
#  'кьюриосити_S',
#  'отыскивать_V',
#  'один_A',
#  'из_P',
#  'хороший_A',
#  'свидетельство_S',
#  'существование_S',
#  'жидкий_A',
#  'вода_S',
#  'в_P',
#  'кратер_S',
#  'гейл_S',
#  'в_P',
#  'далекий_A',
#  'прошлое_S',
#  'марс_S',
#  'ровер_S',
#  'обнаруживать_V',
#  'на_P',
#  'скала_S',
#  'волнообразный_A',
#  'текстура_S',
#  'который_A',
#  'сформировываться_V',
#  'когда_C',
#  'скала_S',
#  'быть_V',
#  'дно_S',
#  'неглубокий_A',
#  'озеро_S',
#  'сообщаться_V',
#  'на_P',
#  'сайт_S',
#  'NASA_U',
#  'кьюриосити_S',
#  'работать_V',
#  'на_P',
#  'марс_S',
#  'много_A',
#  'десять_N',
#  'год_S',
#  'преодолевать_V',
#  'за_P',
#  'этот_A',
#  'время_S',
#  'почти_A',
#  'километр_S',
#  'основной_A',
#  'цель_S',
#  'ровер_S',
#  'становиться_V',
#  'пятикилометровый_A',
#  'гора_S',
#  'шарп_S',
#  'располагать_V',
#  'в_P',
#  'центр_S',
#  'кратер_S',
#  'гейл_S',
#  'и_C',
#  'покрывать_V',
#  'массив_S',
#  'из_P',
#  'эродировать_V',
#  'слой_S',
#  'осадочный_A',
#  'порода_S',
#  'там_A',
#  'он_S',
#  'проводить_V',
#  'геологический_A',
#  'исследование_S',
#  'и_C',
#  'изучать_V',
#  'атмосфера_S',
#  'красный_A',
#  'планета_S',
#  'восьмой_A',
#  'февраль_S',
#  'год_S',
#  'команда_S',
#  'ровер_S',
#  'сообщать_V',
#  'что_C',
#  'обнаруживать_V',
#  'один_A',
#  'из_P',
#  'хороший_A',
#  'свидетельство_S',
#  'существование_S',
#  'жидкий_A',
#  'вода_S',
#  'в_P',
#  'кратер_S',
#  'за_P',
#  'весь_A',
#  'время_S',
#  'работа_S',
#  'кьюриосити_S',
#  'подниматься_V',
#  'почти_A',
#  'на_P',
#  'метр_S',
#  'над_P',
#  'основание_S',
#  'гора_S',
#  'шарп_S',
#  'ровер_S',
#  'попадать_V',
#  'в_P',
#  'область_S',
#  'называть_V',
#  'долина_S',
#  'маркерный_A',
#  'полоса_S',
#  'Marker_U',
#  'Band_U',
#  'Valley_U',
#  'тонкий_A',
#  'слой_S',
#  'темный_A',
#  'скала_S',
#  'который_A',
#  'выделяться_V',
#  'на_P',
#  'фон_S',
#  'остальной_A',
#  'часть_S',
#  'гора_S',
#  'порода_S',
#  'здесь_A',
#  'очень_A',
#  'твердый_A',
#  'и_C',
#  'ранее_A',
#  'ровер_S',
#  'не_P',
#  'смочь_V',
#  'получать_V',
#  'они_S',
#  'образец_S',
#  'хотя_C',
#  'сделать_V',
#  'несколько_N',
#  'попытка_S']

# %%
# NLTK
def normalizeNLTK(text):
    tokens = nltk.pos_tag(nltk.word_tokenize(text))
    words = []
    for t in tokens:
        if t[0] != t[1]:
            words.append(t[0]+'_'+t[1])
    return words    
        
# А вот здесь с частеречной разметкой всё плохо, а параметров нет вовсе.
normalizeNLTK(text)
# Out:
# ['Марсоход_JJ',
#  '«_NNP',
#  'Кьюриосити_NNP',
#  '»_NNP',
#  'отыскал_NNP',
#  'одно_NNP',
#  'из_NNP',
#  'лучших_NNP',
#  'свидетельств_NNP',
#  'существования_NNP',
#  'жидкой_NNP',
#  'воды_NNP',
#  'в_NNP',
#  'кратере_NNP',
#  'Гейл_NNP',
#  'в_NNP',
#  'далеком_NNP',
#  'прошлом_NNP',
#  'Марса_NNP',
#  'Ровер_VB',
#  'обнаружил_JJ',
#  'на_NNP',
#  'скалах_NNP',
#  'волнообразную_NNP',
#  'текстуру_NNP',
#  'которая_NNP',
#  'сформировалась_NNP',
#  'когда_NNP',
#  'скалы_NNP',
#  'были_NNP',
#  'дном_NNP',
#  'неглубокого_NNP',
#  'озера_NNP',
#  'сообщается_NNP',
#  'на_NNP',
#  'сайте_NNP',
#  'NASA_NNP',
#  '«_VB',
#  'Кьюриосити_JJ',
#  '»_NNP',
#  'работает_NNP',
#  'на_NNP',
#  'Марсе_NNP',
#  'более_NNP',
#  'десяти_NNP',
#  'лет_NNP',
#  'преодолев_NNP',
#  'за_NNP',
#  'это_NNP',
#  'время_NNP',
#  'почти_VBD',
#  '30_CD',
#  'километров_NN',
#  'Основной_CC',
#  'целью_JJ',
#  'ровера_NNP',
#  'стала_NNP',
#  'пятикилометровая_NNP',
#  'гора_NNP',
#  'Шарпа_NNP',
#  'расположенная_NNP',
#  'в_NNP',
#  'центре_NNP',
#  'кратера_NNP',
#  'Гейл_NNP',
#  'и_NNP',
#  'покрытая_NNP',
#  'массивом_NNP',
#  'из_NNP',
#  'эродированных_NNP',
#  'слоев_NNP',
#  'осадочных_NNP',
#  'пород_NNP',
#  'Там_VB',
#  'он_JJ',
#  'проводит_NNP',
#  'геологические_NNP',
#  'исследования_NNP',
#  'и_NNP',
#  'изучает_NNP',
#  'атмосферу_NNP',
#  'Красной_NNP',
#  'планеты_NNP',
#  'Восьмого_NN',
#  'февраля_JJ',
#  '2023_CD',
#  'года_NNP',
#  'команда_NNP',
#  'ровера_NNP',
#  'сообщила_NNP',
#  'что_NNP',
#  'обнаружила_NNP',
#  'одно_NNP',
#  'из_NNP',
#  'лучших_NNP',
#  'свидетельств_NNP',
#  'существования_NNP',
#  'жидкой_NNP',
#  'воды_NNP',
#  'в_NNP',
#  'кратере_NNP',
#  'за_NNP',
#  'все_NNP',
#  'время_NNP',
#  'работы_NNP',
#  '«_NNP',
#  'Кьюриосити_NNP',
#  '»_NNP',
#  'Поднявшись_VB',
#  'почти_JJ',
#  'на_$',
#  '800_CD',
#  'метров_NNP',
#  'над_NNP',
#  'основанием_NNP',
#  'горы_NNP',
#  'Шарп_NNP',
#  'ровер_NNP',
#  'попал_NNP',
#  'в_NNP',
#  'область_NNP',
#  'названную_NNP',
#  '«_NNP',
#  'Долиной_NNP',
#  'маркерной_NNP',
#  'полосы_NNP',
#  '»_NNP',
#  'Marker_NNP',
#  'Band_NNP',
#  'Valley_NNP',
#  '—_VBP',
#  'тонком_JJ',
#  'слое_NNP',
#  'темных_NNP',
#  'скал_NNP',
#  'который_NNP',
#  'выделяется_NNP',
#  'на_NNP',
#  'фоне_NNP',
#  'остальной_NNP',
#  'части_NNP',
#  'горы_NNP',
#  'Породы_VB',
#  'здесь_JJ',
#  'очень_NNP',
#  'твердые_NNP',
#  'и_NNP',
#  'ранее_NNP',
#  'ровер_NNP',
#  'не_NNP',
#  'смог_NNP',
#  'получить_NNP',
#  'их_NNP',
#  'образец_NNP',
#  'хотя_NNP',
#  'сделал_NNP',
#  'несколько_NNP',
#  'попыток_NNP']

# %%
from collections import Counter # Не считать же частоты самим.

# %%
words = normalizePymorphy(text)
wdict = Counter(words) # Объект сразу посчитает частоты элементов списка.
print(wdict)
print()
print({w:n for w,n in wdict.items() if n>1}) # Посмотрим какие слова встречаются больше одного раза.
# Out:
# Counter({'в_PREP': 5, 'ровер_NOUN': 5, 'на_PREP': 5, 'кьюриосити_NOUN': 3, 'из_PREP': 3, 'кратер_NOUN': 3, 'скала_NOUN': 3, 'гора_NOUN': 3, 'и_CONJ': 3, 'один_ADJF': 2, 'хороший_ADJF': 2, 'свидетельство_NOUN': 2, 'существование_NOUN': 2, 'жидкий_ADJF': 2, 'вода_NOUN': 2, 'гейл_NOUN': 2, 'марс_NOUN': 2, 'обнаружить_VERB': 2, 'который_ADJF': 2, 'год_NOUN': 2, 'за_PREP': 2, 'время_NOUN': 2, 'почти_ADVB': 2, 'шарп_NOUN': 2, 'слой_NOUN': 2, 'порода_NOUN': 2, 'марсоход_NOUN': 1, 'отыскать_VERB': 1, 'далёкий_ADJF': 1, 'прошлый_ADJF': 1, 'волнообразный_ADJF': 1, 'текстура_NOUN': 1, 'сформироваться_VERB': 1, 'когда_CONJ': 1, 'быть_VERB': 1, 'дно_NOUN': 1, 'неглубокий_ADJF': 1, 'озеро_NOUN': 1, 'сообщаться_VERB': 1, 'сайт_NOUN': 1, 'nasa_None': 1, 'работать_VERB': 1, 'более_ADVB': 1, 'десять_NUMR': 1, 'преодолеть_GRND': 1, 'это_PRCL': 1, 'километр_NOUN': 1, 'основной_ADJF': 1, 'цель_NOUN': 1, 'стать_VERB': 1, 'пятикилометровый_ADJF': 1, 'расположить_PRTF': 1, 'центр_NOUN': 1, 'покрыть_PRTF': 1, 'массив_NOUN': 1, 'эродировать_PRTF': 1, 'осадочный_ADJF': 1, 'там_ADVB': 1, 'он_NPRO': 1, 'проводить_VERB': 1, 'геологический_ADJF': 1, 'исследование_NOUN': 1, 'изучать_VERB': 1, 'атмосфера_NOUN': 1, 'красный_ADJF': 1, 'планета_NOUN': 1, 'восьмой_ADJF': 1, 'февраль_NOUN': 1, 'команда_NOUN': 1, 'сообщить_VERB': 1, 'что_CONJ': 1, 'всё_PRCL': 1, 'работа_NOUN': 1, 'подняться_GRND': 1, 'метр_NOUN': 1, 'над_PREP': 1, 'основание_NOUN': 1, 'попасть_VERB': 1, 'область_NOUN': 1, 'назвать_PRTF': 1, 'долина_NOUN': 1, 'маркерный_ADJF': 1, 'полоса_NOUN': 1, 'marker_None': 1, 'band_None': 1, 'valley_None': 1, 'тонкий_ADJF': 1, 'тёмный_ADJF': 1, 'выделяться_VERB': 1, 'фон_NOUN': 1, 'остальной_ADJF': 1, 'часть_NOUN': 1, 'здесь_ADVB': 1, 'очень_ADVB': 1, 'твёрдый_ADJF': 1, 'ранее_ADVB': 1, 'не_PRCL': 1, 'смочь_VERB': 1, 'получить_INFN': 1, 'они_NPRO': 1, 'образец_NOUN': 1, 'хотя_CONJ': 1, 'сделать_VERB': 1, 'несколько_ADVB': 1, 'попытка_NOUN': 1})
#
# {'кьюриосити_NOUN': 3, 'один_ADJF': 2, 'из_PREP': 3, 'хороший_ADJF': 2, 'свидетельство_NOUN': 2, 'существование_NOUN': 2, 'жидкий_ADJF': 2, 'вода_NOUN': 2, 'в_PREP': 5, 'кратер_NOUN': 3, 'гейл_NOUN': 2, 'марс_NOUN': 2, 'ровер_NOUN': 5, 'обнаружить_VERB': 2, 'на_PREP': 5, 'скала_NOUN': 3, 'который_ADJF': 2, 'год_NOUN': 2, 'за_PREP': 2, 'время_NOUN': 2, 'почти_ADVB': 2, 'гора_NOUN': 3, 'шарп_NOUN': 2, 'и_CONJ': 3, 'слой_NOUN': 2, 'порода_NOUN': 2}

# %% [markdown]
# Фактически, выше мы провели преобразование текста в вектор. Пространство вектора определено на словаре текста - количество измерений совпадает с количеством слов, каждому измерению сопоставлено какое-то слово и отложена его частота. Подобный подход называют мешком слов (Bag of Words, BoW), так как все слова перемешиваются, их порядок больше не соблюдается, а сами слова сваливаются в один "мешок".
#
# ![](img/donkey_carrot_text.png)

# %% [markdown]
# Обратите внимание на распределение частот в отдельных словах и парах. Такое распределение называется [распределением Ципфа](https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%BA%D0%BE%D0%BD_%D0%A6%D0%B8%D0%BF%D1%84%D0%B0) и является характерным практически для любого распределения частот слов и их комбинаций в текстах на любом естественном языке.
#
# $p_i=\frac{p_0}{\beta^{-\alpha*i}}$, где $\alpha\approx1$.
#
# ![](https://upload.wikimedia.org/wikipedia/ru/thumb/d/d8/WikipediaZipf20061023.png/450px-WikipediaZipf20061023.png)
#
# Но вообще, для расчета частот существует CountVectorizer, который позволяет сделать это всё за один раз и очень хорошо ложится в конвейер.

# %% [markdown]
# Кстати, всё то же самое можно было посчитать при помощи класса [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) из библиотеки [skLearn](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature_extraction.text). Но её мы оставим на самостоятельное изучение.

# %% [markdown]
# А теперь обратите внимание на ещё пару фактов. Во-первых, наиболее частотными оказали служебные слова. Во-вторых, не все слова из аннотации, написанной человеком, вошли в список наиболее частотных.

# %%
print({w:n for w,n in wdict.items() if n>1})
# Out:
# {'кьюриосити_NOUN': 3, 'один_ADJF': 2, 'из_PREP': 3, 'хороший_ADJF': 2, 'свидетельство_NOUN': 2, 'существование_NOUN': 2, 'жидкий_ADJF': 2, 'вода_NOUN': 2, 'в_PREP': 5, 'кратер_NOUN': 3, 'гейл_NOUN': 2, 'марс_NOUN': 2, 'ровер_NOUN': 5, 'обнаружить_VERB': 2, 'на_PREP': 5, 'скала_NOUN': 3, 'который_ADJF': 2, 'год_NOUN': 2, 'за_PREP': 2, 'время_NOUN': 2, 'почти_ADVB': 2, 'гора_NOUN': 3, 'шарп_NOUN': 2, 'и_CONJ': 3, 'слой_NOUN': 2, 'порода_NOUN': 2}

# %% [markdown]
# Напишем функцию, которая бы оставляла слова только со значимыми частями речи (краткое и полное прилагательное, существительное, глагол, краткая и полная формы причастия, деепричастие).

# %%
imp_POS = ['ADJF', 'ADJS', 'NOUN', 'VERB', 'PRTF', 'PRTS', 'GRND']

def getMostFrequentWordsFiltered(text):
    
    tokens = re.findall('[A-Za-zА-Яа-яЁё]+\-[A-Za-zА-Яа-яЁё]+|[A-Za-zА-Яа-яЁё]+', text)
    words = []
    for t in tokens:
        pv = morph.parse(t)
        if pv[0].tag.POS in imp_POS and pv[0].normal_form != 'быть':
            words.append(pv[0].normal_form)
    wdict = Counter(words)
    wdict = {w:n for w,n in wdict.items() if n>1}
    return sorted(wdict.items(), key = lambda x: x[1], reverse=True)

# %%
getMostFrequentWordsFiltered(text)
# Out:
# [('ровер', 5),
#  ('кьюриосити', 3),
#  ('кратер', 3),
#  ('скала', 3),
#  ('гора', 3),
#  ('один', 2),
#  ('хороший', 2),
#  ('свидетельство', 2),
#  ('существование', 2),
#  ('жидкий', 2),
#  ('вода', 2),
#  ('гейл', 2),
#  ('марс', 2),
#  ('обнаружить', 2),
#  ('который', 2),
#  ('год', 2),
#  ('время', 2),
#  ('шарп', 2),
#  ('слой', 2),
#  ('порода', 2)]

# %% [markdown]
# Представим себе, что мы взяли много текстов и для каждого из них посчитали вектор слов. Результатом работы является [разреженная матрица](https://docs.scipy.org/doc/scipy/reference/sparse.html) частот слов. Если мы возьмем большое количество текстов, то в кажом из них встречается не так много разных слов, но словарь всех текстов вместе будет огромен. Обработка текстов должна вестись в едином пространстве. Пусть это будет пространство словаря всех текстов (в противном случае у каждого текста будет свое собственное пространство, что чрезвычайно неудобно). Получается, что для текста с маленьким словарем мы должны хранить большое число нулей. Для того, чтобы этого избежать, хранят, например, один раз номер строки, индексы ненулевых значений и сами значения, то есть чуть больше двух чисел на ненулевое значение. Если считать, что словарь заметки - 100 слов, а словарь всех текстов - 100 000 слов, мы получаем экономию места в 500 раз. То, что считалось на кластере, теперь может считаться на недобуке с 2 Гб оперативной памяти.
#
# ![](img/term-document-matrix-bow-annotated.png)
# Изображение взято [отсюда](https://livebook.manning.com/book/natural-language-processing-in-action/chapter-4/v-4/61).

# %% [markdown]
# Теперь попробуем другой показатель для подсчета важности слов в тексте - $TF*IDF$. Здесь $TF$ - Term Frequency, частота термина в документе, а $IDF$ - Inverted Document Frequency, обратная частота термина в коллекции (количество документов, в которых встречается данный термин).
#
# Идея метрики очень проста. Если слово встречается почти во всех документах - его различительная сила очень мала и само слово не является важным. Если слово часто встречается в данном документе, то оно являетсяя важным для него.
#
#
# ![](img/term-document-matrix-tfidf-annotated.png)
# Изображение взято [отсюда](https://livebook.manning.com/book/natural-language-processing-in-action/chapter-4/v-4/61).
#
#
# Метрика считается на коллекции документов для каждого слова, каждого документа. Для расчета меры можно использовать `TfidfVectorizer`, который работает так же как `CountVectorizer`.

# %% [markdown]
# Но нам необходимо искать новости, которые интересны пользователю.
#
# Для определения меры сходства двух статей теперь может использоваться косинусная мера сходства, рассчитываемая по следующей формуле: $cos(a,b)=\frac{\sum{a_i * b_i}}{\sqrt {\sum{a_i^2}*\sum{b_i^2}}}$.
#
# Косинусная мера сходство смотрит не на близость конечных точек, а на то, в какую сторону направлены векторы.
#
# ![](img/cosine_watch.jpg)
#
# Вообще-то, использовать стандартную функцию рассчета косинусной меры сходства из <a href="http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html">sklearn</a> было бы быстрее. Но в данной задаче нам бы пришлось сводить все словари в один, чтобы на одних и тех же местах в векторе были частоты одних и тех же слов. Чтобы избежать подобной работы, напишем собственную функцию рассчета косинусного расстояния, работающую с разреженными векторами в виде питоновских словарей.

# %% [markdown]
# Здесь следует остановиться на том, что косинусная мера является мерой расстояния между объектами, причем подобных мер существует достаточно много. Обычно мы используем Евклидово расстояние: $d_E=\sqrt{\sum {(a_i-b_i)^2}}$. Но при обработке текстов оно работает гораздо хуже. Представим себе, что у нас есть два текста: текст статьи и текст статьи, объединенный с самим собой. Евклидово расстояние между ними будет значительным, тогда как содержание не изменится.
#
# Помимо Евклидового расстояния часто используется Манхэттенское расстояние (расстояние городских кварталов). Если взглянуть на карту Манхэттена, то мы увидим, что практически все улицы параллельны и перпендикулярны друг другу. Это означает, что выбирая любой не удлинняющий маршрут из одной точки в другую я пройду одно и то же расстояние: $d_M=\sum {|a_i-b_i|}$. Манхэттенское расстояние используется в тех случаях, когда мы берем, например, взвешенную сумму параметров с тем, чтобы получить единую оценку. Например, оценивая различные офисы мы складываем с некоторыми коэффициентами стоимость, площадь, расстояние от центра или дома, оценку инфраструктуры и так далее. Аналогично можно брать разницу между двумя векторными представлениями офисов, чтобы найти насколько они сходны.
#
# Расстояние Жаккара берет отношение размера пересечения словарей к их объединению: $d_J=\frac{A \cup B}{A \cap B}$. Эта мера проверяет степень совпадения словарей двух текстов. Если словари совпадают полностью, то тексты, скорее всего, говорят об одном и том же.
#
# Однако, в одном тексте может обсуждаться производство шестеренок, а во вводной части однажды будет упомянуто, что они необходимы для сбора механизмов, тогда как в другом тексте будут обсуждаться сами механизмы с единственным упоминанием, что они состоят из шестеренок. Случайное появление отдельных слов сделает тексты более похожими, чем это следует из их содержания. Этот недостаток устраняет косинусная мера сходства: $d_{cos}=\frac{\sum{a_i * b_i}}{\sqrt {\sum{a_i^2}*\sum{b_i^2}}}$. Если в одном из текстов не встречается слово из другого текста, то соответствующий член суммы в числителе будет равен нулю. Если в одном тексте слово встречается часто, а в другом редко, произведение не будет слишком большим. Проблему представляет случай, когда в обоих текстах есть несколько очень часто встречающихся слов. Тогда их произведение будет забивать все остальные слова, искажая общий смысл.
#
# Следует иметь в виду, что косинусная мера сходства является величиной, обратно зависящей от расстояния: два одинаковых текста будут иметь косинусное сходство равное 1, тогда как расстояние между ними равно нулю, и наоборот.
#
# В качестве мер расстояния также используются [корреляция](https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F) и [дивергенция Кулльбака-Лейблера](https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%9A%D1%83%D0%BB%D1%8C%D0%B1%D0%B0%D0%BA%D0%B0_%E2%80%94_%D0%9B%D0%B5%D0%B9%D0%B1%D0%BB%D0%B5%D1%80%D0%B0).

# %% [markdown]
# ## Синтаксический анализатор SpaCy
#
# Одним из синтаксических анализаторов является Spacy. Библиотеки можно поставить при помощи pip, а как добавить **языковые модели** можно посмотреть [здесь](https://spacy.io/usage/models).

# %%
# Импортируемм нужные библиотеки.
import spacy
from spacy import displacy
from pprint import pprint
from collections import defaultdict
from tqdm import tqdm

# %%
# Загружаем языковую модель.
nlp = spacy.load("ru_core_news_sm")

# %% [markdown]
# Для анализа используем тексты новостей с сайта Лента.ру.

# %%
with open("data/lenta2018.txt", encoding="utf-8") as news_file: # Файл с новостями.
    text_news = [n.split("-----\n")[1] for n in news_file.read().split("=====\n")[1:]]

# %%
text_news[11]
# Out:
# 'Ракета-носитель «Союз-2.1а» с 11 спутниками стартовала с космодрома Восточный. Об этом сообщает Космический центр «Южный», который ведет прямую трансляцию запуска.Корабль должен доставить на орбиты 11 спутников, два из которых — российские спутники дистанционного зондирования Земли «Канопус-В» №3 и №4.Это уже третий пуск с Восточного. Предыдущий состоялся 28 ноября 2017 года и завершился неудачей — из-за неполадок с разгонным блоком была утеряна головная часть ракеты «Союз-2.1б» (с 19 спутниками на борту). В госкорпорации «Роскосмос» объяснили инцидент ошибкой в программном обеспечении разгонного блока и ракеты-носителя, заложенной еще 20 лет назад. Позже вице-премьер России Дмитрий Рогозин заявил, что при подготовке запуска сотрудники перепутали космодромы: «Союз-2.1б» запускали с Восточного, при этом параметры траектории рассчитали с учетом старта с Байконура.В ближайшие годы «Роскосмос» ставит задачу повысить долю успешных запусков ракет-носителей до 99 процентов.\n'

# %% [markdown]
# Дерево в Spacy представляется в виде дерева зависимостей: как совокупность вершин и связей между ними. Каждая вершина соответствует слову из предложения, у слова есть лемма (поле `lemma_`) и токен (поле `text`).

# %%
# Передаем текст новости в Spacy для разбора, получаем объект документа с результатами разбора.
doc = nlp(text_news[11])
# Перебираем предложения в тексте. 
# Но так как мне нужны первые два предложения, я превращаю итерируемый объект sents в список.
for s in list(doc.sents)[:2]:
    pprint(list([f'{t.lemma_} ({t.text})' for t in s]))
# Out:
# ['ракета (Ракета)',
#  '- (-)',
#  'носитель (носитель)',
#  '" («)',
#  'союз-2.1а (Союз-2.1а)',
#  '" (»)',
#  'с (с)',
#  '11 (11)',
#  'спутник (спутниками)',
#  'стартовать (стартовала)',
#  'с (с)',
#  'космодром (космодрома)',
#  'восточный (Восточный)',
#  '. (.)']
# ['Об (Об)',
#  'это (этом)',
#  'сообщать (сообщает)',
#  'космический (Космический)',
#  'центр (центр)',
#  '" («)',
#  'южный (Южный)',
#  '" (»)',
#  ', (,)',
#  'который (который)',
#  'вести (ведет)',
#  'прямой (прямую)',
#  'трансляция (трансляцию)',
#  'запуск (запуска)',
#  '. (.)']

# %% [markdown]
# Вместе со Spacy ставится библиотека dasplaycy, которая умеет отображать текст в виде деревьев зависимости. Посмотрим на первые два предложения.

# %%
for s in list(doc.sents)[:2]:
    displacy.render(s, style="dep", minify=True, jupyter=True, options={"distance":90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="cf8a5c08bda74725ad727c874e704939-0" class="displacy" width="950" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="50">Ракета-</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="140">носитель «</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="230">Союз-2.1а»</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="320">с</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="410">11</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="500">спутниками</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="590">стартовала</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="680">с</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="770">космодрома</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="860">Восточный.</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PROPN</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-cf8a5c08bda74725ad727c874e704939-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 590.0,2.0 590.0,182.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-cf8a5c08bda74725ad727c874e704939-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath></text><path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-cf8a5c08bda74725ad727c874e704939-0-1" stroke-width="2px" d="M160,182.0 C160,47.0 585.0,47.0 585.0,182.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-cf8a5c08bda74725ad727c874e704939-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath></text><path class="displacy-arrowhead" d="M160,184.0 L152,172.0 168,172.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-cf8a5c08bda74725ad727c874e704939-0-2" stroke-width="2px" d="M160,182.0 C160,137.0 215.0,137.0 215.0,182.0" fill="none" stroke="currentColor"/><text dy="1.25 ...
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="429521e1e76448b8865052b02eb2922e-0" class="displacy" width="1040" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="50">Об</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="140">этом</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PRON</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="230">сообщает</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="320">Космический</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="410">центр «</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="500">Южный»,</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="590">который</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PRON</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="680">ведет</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="770">прямую</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="860">трансляцию</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="950">запуска.</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-429521e1e76448b8865052b02eb2922e-0-0" stroke-width="2px" d="M70,92.0 C70,47.0 135.0,47.0 135.0,92.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-429521e1e76448b8865052b02eb2922e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath></text><path class="displacy-arrowhead" d="M70,94.0 L62,82.0 78,82.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-429521e1e76448b8865052b02eb2922e-0-1" stroke-width="2px" d="M160,92.0 C160,47.0 225.0,47.0 225.0,92.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-429521e1e76448b8865052b02eb2922e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath></text><path class="displacy-arrowhead" d="M160,94.0 L152,82.0 168,82.0" fill="currentColor"/></g ...

# %% [markdown]
# Для предложения определено свойство `root`, которое является корневой вершиной предложения.
# Помимо леммы и токена, каждая вершина хранит список потомков `children`, список родителей `ancestors`, вид зависимости (роль слова при родителе) `dep_`, часть речи `tag_`.

# %%
sent0 = list(doc.sents)[0]
childs0 = list(sent0.root.children)
print(sent0.root, childs0)
print(childs0[0].lemma_, childs0[0].text, childs0[0].dep_, childs0[0].tag_, '->', list(childs0[0].ancestors)[0])
# Out:
# стартовала [Ракета, -, носитель, спутниками, космодрома, .]
# ракета Ракета nsubj NOUN -> стартовала

# %% [markdown]
# При анализе текстов существует задача оценки тональности текста. Тональность текста определяет какого роде слова содержатся в тексте - негативные или позитивные. Например, если у нас имеется отзыв на какой-то товар, услугу или организацию, мы можем определить, положительный это отзыв или отрицательный. Для оценки тональности отзыва используют, среди прочего, словари оценочной лексики.
#
# Один отзыв может содержать как критику, так и похвалу, в зависимости от того, что в нем рассматривается (Прекрасное обслуживание, но пироженые были несвежими). Код ниже использует словарь оценочной лексики для того, чтобы понять, какие глаголы сочетаются чаще с отрицательно окрашенными словами, а какие - с положительными.

# %%
# Загружаем словарь оценочной лексики.
with open("data/rusentilex_2017.txt", encoding="utf-8") as senti_file: 
    for i in range(18): # Пропускаем заголовок файла.
        _ = senti_file.readline()
        
    senti_words = {line.split(", ")[0]: line.split(", ")[3] for line in senti_file.readlines()}

# %%
# Посмотрим на первые 10 слов словаря.
list(senti_words.items())[:10]
# Out:
# [('аборт', 'negative'),
#  ('абортивный', 'negative'),
#  ('абракадабра', 'negative'),
#  ('абсурд', 'negative'),
#  ('абсурдность', 'negative'),
#  ('абсурдный', 'negative'),
#  ('авантюра', 'negative'),
#  ('авантюризм', 'negative'),
#  ('авантюрист', 'negative'),
#  ('авантюристический', 'negative')]

# %%
# Поиск эмоционально окрашенных потомков для SpaCy.
def find_sentiments_spacy(node, senti_words, sentiments):
    for child in node.children:
        if child.lemma_ in senti_words.keys():
            if node.lemma_ not in sentiments.keys():
                sentiments[node.lemma_] = defaultdict(int)
            sentiments[node.lemma_][senti_words[child.lemma_]] += 1

# %%
# Перебираем все прдложения первой новости и ищем эмоционально окрашенные слова.
sentiments = {}
for sent in doc.sents:
    find_sentiments_spacy(sent.root, senti_words, sentiments)
sentiments
# Out:
# {'объяснить': defaultdict(int, {'negative': 2}),
#  'заявить': defaultdict(int, {'negative': 1})}

# %%
# Найдем все эмоционально окрашенные фразы во всех новостях.
sentiments = {}
for sent_text in tqdm(text_news):
    doc = nlp(sent_text)
    for sentence in doc.sents:
        find_sentiments_spacy(sentence.root, senti_words, sentiments)
# Out:
# 100%|███████████████████████████████████████| 1708/1708 [01:42<00:00, 16.73it/s]

# %%
[(senti, vals) for senti,vals in sentiments.items() if vals['negative']>30], '\n----\n',\
[(senti, vals) for senti,vals in sentiments.items() if vals['positive']>30]
# Out:
# ([('признать',
#    defaultdict(int, {'negative': 44, 'positive': 7, 'neutral': 2})),
#   ('стать',
#    defaultdict(int,
#                {'negative': 42,
#                 'positive': 35,
#                 'neutral': 18,
#                 'positive/negative': 3})),
#   ('мочь',
#    defaultdict(int,
#                {'negative': 34,
#                 'positive': 18,
#                 'neutral': 11,
#                 'positive/negative': 3,
#                 'пострадать': 1})),
#   ('произойти',
#    defaultdict(int,
#                {'negative': 58,
#                 'positive/negative': 2,
#                 'neutral': 5,
#                 'positive': 4}))],
#  '\n----\n',
#  [('принять', defaultdict(int, {'positive': 39, 'neutral': 4, 'negative': 5})),
#   ('обратить', defaultdict(int, {'positive': 64, 'negative': 2})),
#   ('стать',
#    defaultdict(int,
#                {'negative': 42,
#                 'positive': 35,
#                 'neutral': 18,
#                 'positive/negative': 3}))])

# %% [markdown]
# ## Синтаксический анализатор Stanza
#
# Одним из синтаксических анализаторов является [Stanza](https://stanfordnlp.github.io/stanza/installation_usage.html).

# %%
import stanza

# %%
nlp2 = stanza.Pipeline('ru', use_gpu=False)
# Out:
# 2023-02-25 10:01:03 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2023-02-25 10:01:04 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | pos       | syntagrus |
# | lemma     | syntagrus |
# | depparse  | syntagrus |
# | ner       | wikiner   |
# =========================
#
# 2023-02-25 10:01:04 INFO: Use device: cpu
# 2023-02-25 10:01:04 INFO: Loading: tokenize
# 2023-02-25 10:01:04 INFO: Loading: pos
# 2023-02-25 10:01:04 INFO: Loading: lemma
# 2023-02-25 10:01:04 INFO: Loading: depparse
# 2023-02-25 10:01:04 INFO: Loading: ner
# 2023-02-25 10:01:05 INFO: Done loading processors!

# %%
doc = nlp2(text_news[11])

# %%
doc.sentences[0].words
# Out:
# [{
#    "id": 1,
#    "text": "Ракета",
#    "lemma": "ракета",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#    "head": 12,
#    "deprel": "nsubj",
#    "start_char": 0,
#    "end_char": 6
#  },
#  {
#    "id": 2,
#    "text": "-",
#    "lemma": "-",
#    "upos": "PUNCT",
#    "head": 3,
#    "deprel": "punct",
#    "start_char": 6,
#    "end_char": 7
#  },
#  {
#    "id": 3,
#    "text": "носитель",
#    "lemma": "носитель",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#    "head": 1,
#    "deprel": "appos",
#    "start_char": 7,
#    "end_char": 15
#  },
#  {
#    "id": 4,
#    "text": "«",
#    "lemma": "\"",
#    "upos": "PUNCT",
#    "head": 5,
#    "deprel": "punct",
#    "start_char": 16,
#    "end_char": 17
#  },
#  {
#    "id": 5,
#    "text": "Союз",
#    "lemma": "союз",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#    "head": 3,
#    "deprel": "appos",
#    "start_char": 17,
#    "end_char": 21
#  },
#  {
#    "id": 6,
#    "text": "-",
#    "lemma": "-",
#    "upos": "PUNCT",
#    "head": 7,
#    "deprel": "punct",
#    "start_char": 21,
#    "end_char": 22
#  },
#  {
#    "id": 7,
#    "text": "2.1а",
#    "lemma": "2.1",
#    "upos": "NUM",
#    "feats": "NumType=Card",
#    "head": 5,
#    "deprel": "nummod:entity",
#    "start_char": 22,
#    "end_char": 26
#  },
#  {
#    "id": 8,
#    "text": "»",
#    "lemma": "\"",
#    "upos": "PUNCT",
#    "head": 5,
#    "deprel": "punct",
#    "start_char": 26,
#    "end_char": 27
#  },
#  {
#    "id": 9,
#    "text": "с",
#    "lemma": "с",
#    "upos": "ADP",
#    "head": 11,
#    "deprel": "case",
#    "start_char": 28,
#    "end_char": 29
#  },
#  {
#    "id": 10,
#    "text": "11",
#    "lemma": "11",
#    "upos": "NUM",
#    "feats": "NumType=Card",
#    "head": 11,
#    "deprel": "nummod",
#    "start_char": 30,
#    "end_char": 32
#  },
#  {
#    "id": 11,
#    "text": "спутниками",
#    "lemma": "спутник",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#    "head": 12,
#    "deprel": "obl",
#    "start_char": 33,
#    "end_char": 43
#  },
#  {
#    "id": 12,
#    "text": "стартовала",
#    "lemma": "стартовать",
#    "upos": "VERB",
#    "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#    "head": 0,
#    "deprel": "root",
#    "start_char": 44,
#    "end_char": 54
#  },
#  {
#    "id": 13,
#    "text": "с",
#    "lemma": "с",
#    "upos": "ADP",
#    "head": 14,
#    "deprel": "case",
#    "start_char": 55,
#    "end_char": 56
#  },
#  {
#    "id": 14,
#    "text": "космодрома",
#    "lemma": "космодром",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#    "head": 12,
#    "deprel": "obl",
#    "start_char": 57,
#    "end_char": 67
#  },
#  {
#    "id": 15,
#    "text": "Восточный",
#    "lemma": "восточный",
#    "upos": "PROPN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#    "head": 14,
#    "deprel": "appos",
#    "start_char": 68,
#    "end_char": 77
#  },
#  {
#    "id": 16,
#    "text": ".",
#    "lemma": ".",
#    "upos": "PUNCT",
#    "head": 12,
#    "deprel": "punct",
#    "start_char": 77,
#    "end_char": 78
#  }]

# %%
doc.sentences[0].words[0].lemma
# Out:
# 'ракета'

# %%
doc.sentences[0].dependencies
# Out:
# [({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'nsubj',
#   {
#     "id": 1,
#     "text": "Ракета",
#     "lemma": "ракета",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#     "head": 12,
#     "deprel": "nsubj",
#     "start_char": 0,
#     "end_char": 6
#   }),
#  ({
#     "id": 3,
#     "text": "носитель",
#     "lemma": "носитель",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 1,
#     "deprel": "appos",
#     "start_char": 7,
#     "end_char": 15
#   },
#   'punct',
#   {
#     "id": 2,
#     "text": "-",
#     "lemma": "-",
#     "upos": "PUNCT",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 6,
#     "end_char": 7
#   }),
#  ({
#     "id": 1,
#     "text": "Ракета",
#     "lemma": "ракета",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#     "head": 12,
#     "deprel": "nsubj",
#     "start_char": 0,
#     "end_char": 6
#   },
#   'appos',
#   {
#     "id": 3,
#     "text": "носитель",
#     "lemma": "носитель",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 1,
#     "deprel": "appos",
#     "start_char": 7,
#     "end_char": 15
#   }),
#  ({
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   },
#   'punct',
#   {
#     "id": 4,
#     "text": "«",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "head": 5,
#     "deprel": "punct",
#     "start_char": 16,
#     "end_char": 17
#   }),
#  ({
#     "id": 3,
#     "text": "носитель",
#     "lemma": "носитель",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 1,
#     "deprel": "appos",
#     "start_char": 7,
#     "end_char": 15
#   },
#   'appos',
#   {
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   }),
#  ({
#     "id": 7,
#     "text": "2.1а",
#     "lemma": "2.1",
#     "upos": "NUM",
#     "feats": "NumType=Card",
#     "head": 5,
#     "deprel": "nummod:entity",
#     "start_char": 22,
#     "end_char": 26
#   },
#   'punct',
#   {
#     "id": 6,
#     "text": "-",
#     "lemma": "-",
#     "upos": "PUNCT",
#     "head": 7,
#     "deprel": "punct",
#     "start_char": 21,
#     "end_char": 22
#   }),
#  ({
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   },
#   'nummod:entity',
#   {
#     "id": 7,
#     "text": "2.1а",
#     "lemma": "2.1",
#     "upos": "NUM",
#     "feats": "NumType=Card",
#     "head": 5,
#     "deprel": "nummod:entity",
#     "start_char": 22,
#     "end_char": 26
#   }),
#  ({
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   },
#   'punct',
#   {
#     "id": 8,
#     "text": "»",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "head": 5,
#     "deprel": "punct",
#     "start_char": 26,
#     "end_char": 27
#   }),
#  ({
#     "id": 11,
#     "text": "спутниками",
#     "lemma": "спутник",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 33,
#     "end_char": 43
#   },
#   'case',
#   {
#     "id": 9,
#     "text": "с",
#     "lemma": "с",
#     "upos": "ADP",
#     "head": 11,
#     "deprel": "case",
#     "start_char": 28,
#     "end_char": 29
#   }),
#  ({
#     "id": 11,
#     "text": "спутниками",
#     "lemma": "спутник",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 33,
#     "end_char": 43
#   },
#   'nummod',
#   {
#     "id": 10,
#     "text": "11",
#     "lemma": "11",
#     "upos": "NUM",
#     "feats": "NumType=Card",
#     "head": 11,
#     "deprel": "nummod",
#     "start_char": 30,
#     "end_char": 32
#   }),
#  ({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'obl',
#   {
#     "id": 11,
#     "text": "спутниками",
#     "lemma": "спутник",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 33,
#     "end_char": 43
#   }),
#  ({
#     "id": 0,
#     "text": "ROOT"
#   },
#   'root',
#   {
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   }),
#  ({
#     "id": 14,
#     "text": "космодрома",
#     "lemma": "космодром",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 57,
#     "end_char": 67
#   },
#   'case',
#   {
#     "id": 13,
#     "text": "с",
#     "lemma": "с",
#     "upos": "ADP",
#     "head": 14,
#     "deprel": "case",
#     "start_char": 55,
#     "end_char": 56
#   }),
#  ({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'obl',
#   {
#     "id": 14,
#     "text": "космодрома",
#     "lemma": "космодром",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 57,
#     "end_char": 67
#   }),
#  ({
#     "id": 14,
#     "text": "космодрома",
#     "lemma": "космодром",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 57,
#     "end_char": 67
#   },
#   'appos',
#   {
#     "id": 15,
#     "text": "Восточный",
#     "lemma": "восточный",
#     "upos": "PROPN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 14,
#     "deprel": "appos",
#     "start_char": 68,
#     "end_char": 77
#   }),
#  ({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'punct',
#   {
#     "id": 16,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "head": 12,
#     "deprel": "punct",
#     "start_char": 77,
#     "end_char": 78
#   })]

# %%
# Поиск эмоционально окрашенных потомков для SpaCy.
def find_sentiments_stanza(dependencies, senti_words, sentiments):
    for dep in dependencies:
        if dep[2].lemma in senti_words.keys():
            if dep[0].lemma not in sentiments.keys():
                sentiments[dep[0].lemma] = defaultdict(int)
            sentiments[dep[0].lemma][senti_words[dep[2].lemma]] += 1

# %%
sentiments = {}

for news1 in tqdm(text_news):
    doc = nlp2(news1)

    for sentence in doc.sentences:
        find_sentiments_stanza(sentence.dependencies, senti_words, sentiments)
# Out:
#  22%|████████▋                               | 372/1708 [10:25<37:27,  1.68s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_73965/3701044405.py in <module>
#       2
#       3 for news1 in tqdm(text_news):
# ----> 4     doc = nlp2(news1)
#       5
#       6     for sentence in doc.sentences:
#
# ~/.local/lib/python3.10/site-packages/stanza/pipeline/core.py in __call__(self, doc, processors)
#     406
#     407     def __call__(self, doc, processors=None):
# --> 408         return self.process(doc, processors)
#     409
#
# ~/.local/lib/python3.10/site-packages/stanza/pipeline/core.py in process(self, doc, processors)
#     395             if self.processors.get(processor_name):
#     396                 process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 397                 doc = process(doc)
#     398         return doc
#     399
#
# ~/.local/lib/python3.10/site-packages/stanza/pipeline/ner_processor.py in process(self, document)
#      83             preds = []
#      84             for i, b in enumerate(batch):
# ---> 85                 preds += trainer.predict(b)
#      86             all_preds.append(preds)
#      87         # for each sentence, gather a list of predictions
#
# ~/.local/lib/python3.10/site-packages/stanza/models/ner/trainer.py in predict(self, batch, unsort)
#     116         self.model.eval()
#     117         #batch_size = word.size(0)
# --> 118         _, logits, trans = self.model(word, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#     119
#     120         # decode
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.10/site-packages/stanza/models/ner/model.py in forward(self, sentences, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#     175         if self.args['char'] and self.args['char_emb_dim'] > 0:
#     176             if self.args.get('charlm', None):
# --> 177                 char_reps_forward = self.charmodel_forward.get_representation(chars[0], charoffsets[0], charlens, char_orig_idx)
#     178                 char_reps_forward = PackedSequence(char_reps_forward.data, char_reps_forward.batch_sizes)
#     179                 char_reps_backward = self.charmodel_backward.get_representation(chars[1], charoffsets[1], charlens, char_orig_idx)
#
# ~/.local/lib/python3.10/site-packages/stanza/models/common/char_model.py in get_representation(self, chars, charoffsets, charlens, char_orig_idx)
#     137     def get_representation(self, chars, charoffsets, charlens, char_orig_idx):
#     138         with torch.no_grad():
# --> 139             output, _, _ = self.forward(chars, charlens)
#     140             res = [output[i, offsets] for i, offsets in enumerate(charoffsets)]
#     141             res = unsort(res, char_orig_idx)
#
# ~/.local/lib/python3.10/site-packages/stanza/models/common/char_model.py in forward(self, chars, charlens, hidden)
#     130             hidden = (self.charlstm_h_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous(),
#     131                       self.charlstm_c_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous())
# --> 132         output, hidden = self.charlstm(embs, charlens, hx=hidden)
#     133         output = self.dropout(pad_packed_sequence(output, batch_first=True)[0])
#     134         decoded = self.decoder(output)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.10/site-packages/stanza/models/common/packed_lstm.py in forward(self, input, lengths, hx)
#      20             input = pack_padded_sequence(input, lengths, batch_first=self.batch_first)
#      21
# ---> 22         res = self.lstm(input, hx)
#      23         if self.pad:
#      24             res = (pad_packed_sequence(res[0], batch_first=self.batch_first)[0], res[1])
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     775                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     776         else:
# --> 777             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     778                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     779         output = result[0]
#
# KeyboardInterrupt:

# %%
sentiments
# Out:
# {'комплект': defaultdict(int, {'neutral': 1}),
#  'провести': defaultdict(int, {'neutral': 7, 'negative': 1, 'positive': 1}),
#  'являться': defaultdict(int,
#              {'neutral': 3,
#               'positive': 6,
#               'negative': 7,
#               'positive/negative': 1}),
#  'в': defaultdict(int, {'neutral': 10, 'positive': 2, 'negative': 1}),
#  'головка': defaultdict(int, {'positive': 1}),
#  'отсутствовать': defaultdict(int, {'positive': 1}),
#  'порядок': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'аппаратура': defaultdict(int, {'positive': 1}),
#  'уделяться': defaultdict(int, {'positive': 1}),
#  'Совет': defaultdict(int, {'positive': 3}),
#  'способный': defaultdict(int, {'positive/negative': 3, 'negative': 2}),
#  'сдерживание': defaultdict(int, {'negative': 1}),
#  'выразить': defaultdict(int, {'positive': 2, 'negative': 11, 'neutral': 1}),
#  None: defaultdict(int,
#              {'positive': 157,
#               'negative': 162,
#               'neutral': 29,
#               'positive/negative': 14}),
#  'молеться': defaultdict(int, {'positive': 1}),
#  'покорить': defaultdict(int, {'negative': 1}),
#  'повстречаться': defaultdict(int, {'negative': 1}),
#  'нраво': defaultdict(int, {'positive': 1}),
#  'становиться': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'пинать': defaultdict(int, {'negative': 1}),
#  'демонстрировать': defaultdict(int, {'positive': 3, 'negative': 2}),
#  'культура': defaultdict(int, {'negative': 1}),
#  'обрести': defaultdict(int, {'positive': 2}),
#  'знание': defaultdict(int, {'neutral': 1}),
#  'стиль': defaultdict(int, {'negative': 1}),
#  'аouэubеблогер': defaultdict(int, {'positive': 1}),
#  'владение': defaultdict(int, {'neutral': 1}),
#  'результат': defaultdict(int,
#              {'negative': 5,
#               'neutral': 1,
#               'positive': 1,
#               'positive/negative': 1}),
#  'травма': defaultdict(int, {'positive': 1, 'negative': 3}),
#  'получить': defaultdict(int, {'negative': 16, 'positive': 8, 'neutral': 3}),
#  'почувствовать': defaultdict(int, {'negative': 2}),
#  'оказывать': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'сойти': defaultdict(int, {'negative': 1}),
#  'уточнить': defaultdict(int, {'positive/negative': 2, 'positive': 1}),
#  'страдать': defaultdict(int,
#              {'negative': 5, 'neutral': 1, 'positive/negative': 1}),
#  'разрыть': defaultdict(int, {'negative': 1}),
#  'один': defaultdict(int, {'neutral': 2, 'negative': 2, 'positive': 4}),
#  'аренда': defaultdict(int, {'neutral': 1}),
#  'шлем': defaultdict(int, {'positive': 1}),
#  'роботыИздание': defaultdict(int, {'positive/negative': 1}),
#  'указать': defaultdict(int,
#              {'positive/negative': 1, 'positive': 1, 'negative': 1}),
#  'запретить': defaultdict(int, {'negative': 1}),
#  'намерение': defaultdict(int, {'positive': 1}),
#  'принять': defaultdict(int, {'positive': 14, 'negative': 1, 'neutral': 10}),
#  'импонировать': defaultdict(int, {'positive': 1}),
#  'планировать': defaultdict(int, {'opinion\n': 1, 'neutral': 1}),
#  'обратить': defaultdict(int, {'positive': 22, 'neutral': 1}),
#  'норма': defaultdict(int, {'positive/negative': 1, 'positive': 1}),
#  'радоваться': defaultdict(int, {'positive': 2}),
#  'повод': defaultdict(int, {'positive': 1}),
#  'опрос': defaultdict(int, {'positive': 1}),
#  'превышать': defaultdict(int, {'negative': 1}),
#  'работать': defaultdict(int,
#              {'negative': 2,
#               'neutral': 1,
#               'positive': 2,
#               'positive/negative': 1}),
#  'подлежать': defaultdict(int, {'negative': 1}),
#  'стать': defaultdict(int, {'negative': 23, 'positive': 9, 'neutral': 5}),
#  'техника': defaultdict(int, {'negative': 2}),
#  'признать': defaultdict(int, {'negative': 23, 'positive': 5, 'neutral': 1}),
#  'оборот': defaultdict(int, {'negative': 2}),
#  'лишение': defaultdict(int, {'positive/negative': 1}),
#  'приговор': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'выносить': defaultdict(int, {'negative': 2}),
#  'товар': defaultdict(int, {'positive': 1}),
#  'увеличение': defaultdict(int, {'positive': 1}),
#  'улучшение': defaultdict(int, {'positive': 2}),
#  'материал': defaultdict(int, {'negative': 11, 'positive': 1, 'neutral': 2}),
#  'дом': defaultdict(int, {'positive': 4}),
#  'вода': defaultdict(int, {'positive': 1}),
#  'температура': defaultdict(int, {'neutral': 2}),
#  'вызывать': defaultdict(int, {'negative': 4, 'positive': 1}),
#  'находиться': defaultdict(int,
#              {'negative': 6,
#               'positive': 1,
#               'positive/negative': 2,
#               'neutral': 1}),
#  'фаза': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'сигнал': defaultdict(int, {'negative': 3}),
#  'жилет': defaultdict(int, {'negative': 1}),
#  'домогательство': defaultdict(int, {'positive/negative': 10, 'negative': 1}),
#  'обвинить': defaultdict(int, {'negative': 13, 'positive': 2}),
#  'школа': defaultdict(int, {'neutral': 2}),
#  'сообщить': defaultdict(int, {'пострадать': 1, 'negative': 4, 'positive': 1}),
#  'наставник': defaultdict(int, {'positive': 1}),
#  'принадлежать': defaultdict(int, {'positive': 1}),
#  'обнаружить': defaultdict(int,
#              {'пострадать': 1, 'negative': 3, 'positive': 1}),
#  'арестовывать': defaultdict(int, {'neutral': 2, 'negative': 8}),
#  'обвинение': defaultdict(int, {'negative': 8, 'positive': 1, 'neutral': 1}),
#  'предъявить': defaultdict(int, {'neutral': 7}),
#  'обращение': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'блюдо': defaultdict(int, {'positive': 2}),
#  'вариант': defaultdict(int, {'positive': 1}),
#  'ребенок': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'любить': defaultdict(int, {'positive': 1}),
#  'популярный': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'пицца': defaultdict(int, {'negative': 1, 'neutral': 2}),
#  'должен': defaultdict(int, {'positive': 8, 'neutral': 3, 'negative': 4}),
#  'мультсериал': defaultdict(int, {'positive': 1}),
#  'серия': defaultdict(int, {'positive': 1, 'negative': 3, 'neutral': 1}),
#  'история': defaultdict(int, {'negative': 4, 'positive': 3}),
#  'писать': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'теме20': defaultdict(int, {'negative': 1}),
#  'мочь': defaultdict(int,
#              {'negative': 15,
#               'positive': 11,
#               'positive/negative': 2,
#               'neutral': 1}),
#  'понести': defaultdict(int, {'positive': 2, 'negative': 3}),
#  'ответственность': defaultdict(int, {'negative': 11, 'positive/negative': 1}),
#  'лопаться': defaultdict(int, {'positive': 2}),
#  'брать': defaultdict(int,
#              {'negative': 2, 'positive': 3, 'positive/negative': 1}),
#  'неспособный': defaultdict(int, {'negative': 1}),
#  'наказывать': defaultdict(int, {'negative': 2}),
#  'коллаборационист': defaultdict(int, {'negative': 1}),
#  'навеять': defaultdict(int, {'negative': 1}),
#  'бегство': defaultdict(int, {'negative': 1}),
#  'дело': defaultdict(int, {'negative': 30, 'neutral': 1, 'positive': 2}),
#  'угрожать': defaultdict(int, {'negative': 3}),
#  'задержать': defaultdict(int, {'negative': 4, 'neutral': 2}),
#  'совершение': defaultdict(int, {'negative': 2}),
#  'киевлянин': defaultdict(int, {'negative': 1}),
#  'акция': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'участвовать': defaultdict(int, {'neutral': 3}),
#  'трансляция': defaultdict(int, {'positive': 1}),
#  'завершиться': defaultdict(int, {'negative': 2, 'positive': 3}),
#  'объяснить': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'заявить': defaultdict(int, {'negative': 6, 'positive': 4, 'neutral': 2}),
#  'запуск': defaultdict(int, {'positive': 1}),
#  'дизайнер': defaultdict(int, {'negative': 1}),
#  'известный': defaultdict(int, {'neutral': 1, 'positive': 1, 'negative': 1}),
#  'расследование': defaultdict(int, {'negative': 2, 'positive/negative': 1}),
#  'умереть': defaultdict(int, {'negative': 2}),
#  'войныпервоначально': defaultdict(int, {'positive': 1}),
#  'Гей-деревни': defaultdict(int, {'neutral': 1}),
#  'два': defaultdict(int, {'neutral': 1}),
#  'убийца': defaultdict(int, {'negative': 1}),
#  'оказаться': defaultdict(int, {'neutral': 1, 'negative': 5, 'positive': 8}),
#  'считать': defaultdict(int, {'negative': 13, 'positive': 2, 'neutral': 1}),
#  'выбирать': defaultdict(int, {'negative': 1}),
#  'тест': defaultdict(int, {'neutral': 2, 'positive': 1}),
#  'потерпеть': defaultdict(int,
#              {'negative': 3, 'positive/negative': 3, 'positive': 1}),
#  'проводить': defaultdict(int, {'neutral': 4, 'positive': 1}),
#  'защита': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'отличать': defaultdict(int, {'positive/negative': 1}),
#  'видео': defaultdict(int,
#              {'positive': 5, 'negative': 8, 'positive/negative': 1}),
#  'страна': defaultdict(int, {'neutral': 4, 'positive': 1}),
#  'признавать': defaultdict(int, {'positive': 1, 'neutral': 1, 'negative': 4}),
#  'персона': defaultdict(int, {'positive': 1}),
#  'питание': defaultdict(int, {'positive': 1}),
#  'еда': defaultdict(int, {'positive': 1}),
#  'кусок': defaultdict(int, {'neutral': 1}),
#  'жир': defaultdict(int, {'positive': 1}),
#  'назвать': defaultdict(int,
#              {'positive': 10, 'negative': 8, 'positive/negative': 2}),
#  'выбор': defaultdict(int, {'positive': 1}),
#  'добавка': defaultdict(int, {'negative': 1}),
#  'процесс': defaultdict(int, {'negative': 2}),
#  'прийти': defaultdict(int,
#              {'neutral': 1,
#               'positive/negative': 1,
#               'positive': 2,
#               'negative': 2}),
#  'ускорить': defaultdict(int, {'negative': 1}),
#  'начинаться': defaultdict(int, {'neutral': 1}),
#  'вызвать': defaultdict(int, {'neutral': 2, 'negative': 5}),
#  'омег': defaultdict(int, {'positive': 1}),
#  'кислота': defaultdict(int, {'neutral': 2}),
#  'продукт': defaultdict(int, {'positive': 3}),
#  'заболевание': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'предотвращать': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'функция': defaultdict(int, {'positive': 1}),
#  'защищать': defaultdict(int, {'negative': 1}),
#  'накопление': defaultdict(int, {'negative': 2}),
#  'часть': defaultdict(int,
#              {'negative': 3,
#               'positive/negative': 2,
#               'positive': 1,
#               'neutral': 1}),
#  'анализировать': defaultdict(int, {'positive': 1}),
#  'область': defaultdict(int, {'neutral': 2, 'negative': 2, 'positive': 1}),
#  'ткань': defaultdict(int, {'neutral': 1, 'negative': 4}),
#  'маркер': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'усиливать': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'влиять': defaultdict(int,
#              {'positive': 1, 'positive/negative': 1, 'neutral': 1}),
#  'вернуться': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'директор': defaultdict(int, {'positive': 3}),
#  'туалет': defaultdict(int, {'negative': 1}),
#  'подать': defaultdict(int, {'negative': 4, 'positive': 1, 'neutral': 2}),
#  'выступать': defaultdict(int, {'neutral': 2, 'positive': 3}),
#  'условие': defaultdict(int, {'neutral': 2, 'positive': 2, 'negative': 1}),
#  'соперник': defaultdict(int, {'positive': 1}),
#  'проблема': defaultdict(int,
#              {'positive/negative': 1, 'negative': 2, 'positive': 1}),
#  'связать': defaultdict(int, {'neutral': 1, 'negative': 3, 'positive': 1}),
#  'устранить': defaultdict(int, {'negative': 4, 'neutral': 1}),
#  'причина': defaultdict(int,
#              {'neutral': 1, 'negative': 12, 'positive/negative': 1}),
#  'маскироваться': defaultdict(int, {'negative': 1}),
#  'вид': defaultdict(int, {'negative': 4, 'neutral': 1}),
#  'услуга': defaultdict(int, {'negative': 1}),
#  'второй': defaultdict(int, {'positive': 2}),
#  'наносить': defaultdict(int, {'negative': 1}),
#  'запугивание': defaultdict(int, {'negative': 1}),
#  'контент': defaultdict(int, {'negative': 3, 'positive/negative': 1}),
#  'ролик': defaultdict(int, {'positive': 3, 'negative': 4}),
#  'обещать': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'оставить': defaultdict(int, {'neutral': 1, 'positive': 3}),
#  'объяснять': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'положение': defaultdict(int, {'neutral': 1}),
#  'делать': defaultdict(int,
#              {'negative': 3,
#               'positive': 5,
#               'positive/negative': 1,
#               'neutral': 3}),
#  'мишень': defaultdict(int, {'positive': 1}),
#  'подстегнуть': defaultdict(int, {'negative': 1}),
#  'сайт': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'возможный': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'обойти': defaultdict(int, {'neutral': 1, 'positive/negative': 1}),
#  'ловушка': defaultdict(int, {'negative': 1}),
#  'ошибка': defaultdict(int, {'negative': 1, 'positive/negative': 1}),
#  'привести': defaultdict(int, {'negative': 8, 'positive': 2}),
#  'последствие': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'перехват': defaultdict(int, {'negative': 1}),
#  'допускать': defaultdict(int, {'negative': 1}),
#  'прекратить': defaultdict(int, {'negative': 1}),
#  'Фонд': defaultdict(int, {'positive': 2}),
#  'предусмотреть': defaultdict(int, {'positive': 2, 'positive/negative': 1}),
#  'фонд': defaultdict(int, {'positive': 2}),
#  'подушка': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'финансирование': defaultdict(int, {'negative': 3}),
#  'случай': defaultdict(int, {'positive/negative': 1, 'negative': 8}),
#  'факт': defaultdict(int, {'negative': 6, 'positive': 1}),
#  'отмывание': defaultdict(int, {'negative': 2}),
#  'атлетика': defaultdict(int, {'positive': 1}),
#  'компания': defaultdict(int,
#              {'positive': 1, 'positive/negative': 2, 'negative': 1}),
#  'схема': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'выплата': defaultdict(int, {'negative': 1}),
#  'скрывать': defaultdict(int, {'negative': 3}),
#  'терпеть': defaultdict(int, {'negative': 1}),
#  'начальница': defaultdict(int, {'negative': 1}),
#  'выдерживать': defaultdict(int, {'positive': 1}),
#  'начинать': defaultdict(int, {'negative': 2}),
#  'выражение': defaultdict(int, {'negative': 1}),
#  'поза': defaultdict(int, {'negative': 1}),
#  'снимок': defaultdict(int, {'positive': 1}),
#  'набрать': defaultdict(int, {'positive': 1}),
#  'боль': defaultdict(int, {'negative': 3, 'positive/negative': 1}),
#  'видеть': defaultdict(int, {'negative': 2, 'positive': 3, 'neutral': 1}),
#  'данные': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'преступление': defaultdict(int, {'neutral': 1, 'negative': 3}),
#  'деяние': defaultdict(int, {'negative': 1}),
#  'число': defaultdict(int, {'negative': 5, 'neutral': 1}),
#  'тысяча': defaultdict(int, {'negative': 2}),
#  'количество': defaultdict(int, {'negative': 6, 'neutral': 2}),
#  'совершать': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'уровень': defaultdict(int, {'neutral': 1, 'negative': 2, 'positive': 2}),
#  'малый': defaultdict(int, {'negative': 1}),
#  'аттестат': defaultdict(int, {'positive': 1}),
#  'образование': defaultdict(int, {'neutral': 1, 'positive': 1, 'negative': 1}),
#  'ракета': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'сообщаться': defaultdict(int, {'positive': 1}),
#  'подробность': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'хранить': defaultdict(int, {'positive': 1}),
#  'деятельность': defaultdict(int, {'negative': 13, 'positive': 2}),
#  'завод': defaultdict(int, {'negative': 1}),
#  'опубликовать': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'отбить': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'контролировать': defaultdict(int, {'positive': 1}),
#  'место': defaultdict(int,
#              {'positive': 4,
#               'neutral': 1,
#               'negative': 1,
#               'positive/negative': 3}),
#  'уйти': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'Джабхат': defaultdict(int, {'negative': 2}),
#  'бой': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'ответ': defaultdict(int, {'positive': 5}),
#  'задачка': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'счесть': defaultdict(int, {'positive': 1, 'negative': 3}),
#  'вес': defaultdict(int, {'neutral': 2, 'positive': 2, 'negative': 1}),
#  'приблизиться': defaultdict(int, {'negative': 1}),
#  'спор': defaultdict(int, {'positive': 2}),
#  'намекнуть': defaultdict(int, {'negative': 1}),
#  'мышление': defaultdict(int, {'neutral': 1}),
#  'огорчиться': defaultdict(int, {'negative': 1}),
#  'извинение': defaultdict(int, {'positive': 1}),
#  'просить': defaultdict(int, {'negative': 2, 'positive': 2, 'neutral': 1}),
#  'то': defaultdict(int,
#              {'negative': 3,
#               'positive': 6,
#               'positive/negative': 1,
#               'neutral': 1}),
#  'ужасный': defaultdict(int, {'negative': 1}),
#  'политик': defaultdict(int, {'negative': 1}),
#  'рассказать': defaultdict(int, {'negative': 6, 'neutral': 2, 'positive': 1}),
#  'трусы': defaultdict(int, {'neutral': 1}),
#  'котомомент': defaultdict(int, {'positive': 1}),
#  'доказать': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'наклонность': defaultdict(int, {'negative': 1}),
#  'ходить': defaultdict(int, {'negative': 1}),
#  'сосед': defaultdict(int, {'negative': 1}),
#  'Петербург': defaultdict(int, {'negative': 2}),
#  'дискуссия': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'сериал': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'человек': defaultdict(int, {'positive': 10}),
#  'пропаганда': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'бандитизм': defaultdict(int, {'negative': 1}),
#  'подчеркнуть': defaultdict(int,
#              {'positive': 1, 'positive/negative': 1, 'negative': 1}),
#  'фильм': defaultdict(int, {'negative': 4, 'positive': 2}),
#  'пропагандировать': defaultdict(int, {'negative': 1}),
#  'убиватьскать': defaultdict(int, {'negative': 1}),
#  'урок': defaultdict(int, {'negative': 1}),
#  'бригада': defaultdict(int, {'negative': 1}),
#  'огнемет': defaultdict(int, {'positive': 1}),
#  'включить': defaultdict(int, {'neutral': 1, 'negative': 1, 'positive': 1}),
#  'оружие': defaultdict(int, {'negative': 2, 'positive': 4}),
#  'огнетушитель': defaultdict(int, {'positive': 1}),
#  'контейнер': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'кормить': defaultdict(int, {'negative': 2}),
#  'модель': defaultdict(int, {'neutral': 1, 'positive': 1, 'negative': 2}),
#  'образец': defaultdict(int, {'neutral': 1}),
#  'вскрыть': defaultdict(int, {'negative': 1}),
#  'заявлять': defaultdict(int, {'negative': 1, 'neutral': 1, 'positive': 2}),
#  'убить': defaultdict(int, {'positive': 3, 'negative': 4}),
#  'ИГ': defaultdict(int, {'negative': 5}),
#  'готовить': defaultdict(int, {'negative': 3}),
#  'оператор': defaultdict(int, {'negative': 1}),
#  'оказать': defaultdict(int, {'negative': 7, 'positive': 4}),
#  'устройство': defaultdict(int, {'negative': 4}),
#  'организация': defaultdict(int, {'negative': 10, 'positive': 3}),
#  'акт': defaultdict(int, {'negative': 1}),
#  'теракт': defaultdict(int, {'positive': 1}),
#  'страхование': defaultdict(int, {'positive': 2}),
#  'забрать': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'объявление': defaultdict(int, {'negative': 1}),
#  'рамка': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'совершить': defaultdict(int, {'negative': 6}),
#  'треть': defaultdict(int, {'positive/negative': 1}),
#  'оспаривать': defaultdict(int, {'positive/negative': 1}),
#  'вынести': defaultdict(int, {'positive': 1, 'negative': 4}),
#  'сказать': defaultdict(int, {'positive': 3, 'negative': 2}),
#  'касаться': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'сумма': defaultdict(int, {'positive': 1, 'neutral': 1, 'negative': 2}),
#  'дата': defaultdict(int, {'positive': 1}),
#  'неплатежеспособность': defaultdict(int, {'neutral': 1}),
#  'состояние': defaultdict(int, {'negative': 4, 'positive/negative': 2}),
#  'рост': defaultdict(int, {'positive': 2}),
#  'задействовать': defaultdict(int, {'neutral': 1}),
#  'БМП': defaultdict(int, {'neutral': 1}),
#  'пойти': defaultdict(int, {'neutral': 1, 'negative': 2}),
#  'дорогой': defaultdict(int, {'neutral': 1, 'positive': 2}),
#  'сложный': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'расти': defaultdict(int, {'positive': 1}),
#  'аннулировать': defaultdict(int,
#              {'positive': 7, 'positive/negative': 4, 'negative': 1}),
#  'участие': defaultdict(int, {'negative': 10, 'positive': 2}),
#  'список': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'подтвердить': defaultdict(int, {'neutral': 1, 'positive': 3, 'negative': 2}),
#  'виновный': defaultdict(int, {'negative': 10}),
#  'отстранение': defaultdict(int, {'negative': 2, 'positive': 3, 'neutral': 1}),
#  'запрет': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'общаться': defaultdict(int, {'positive': 1}),
#  'Игра': defaultdict(int, {'negative': 2}),
#  'отстранить': defaultdict(int, {'positive': 4}),
#  'пользоваться': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'самолет': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'погибнуть': defaultdict(int,
#              {'negative': 2, 'positive': 2, 'positive/negative': 1}),
#  'просьба': defaultdict(int, {'positive': 1}),
#  'купить': defaultdict(int, {'negative': 1}),
#  'горе': defaultdict(int, {'positive': 1}),
#  'нажиться': defaultdict(int, {'negative': 1}),
#  'ущерб': defaultdict(int, {'positive': 2}),
#  'причинение': defaultdict(int, {'negative': 6}),
#  'родственник': defaultdict(int, {'negative': 4}),
#  'привлекать': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'выжить': defaultdict(int, {'negative': 1}),
#  'сотрясение': defaultdict(int, {'positive': 1}),
#  'технология': defaultdict(int, {'negative': 1}),
#  'пригодный': defaultdict(int, {'negative': 1}),
#  'орбита': defaultdict(int, {'neutral': 2}),
#  'спутник': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'уязвимый': defaultdict(int, {'positive': 1}),
#  'лагерь': defaultdict(int, {'negative': 3}),
#  'год': defaultdict(int, {'neutral': 6, 'negative': 16}),
#  'надо': defaultdict(int, {'negative': 5, 'positive': 1}),
#  'подготовить': defaultdict(int, {'negative': 4, 'positive': 2}),
#  'идеология': defaultdict(int, {'negative': 2}),
#  'отрицание': defaultdict(int, {'negative': 4, 'positive': 2}),
#  'помогать': defaultdict(int, {'negative': 2}),
#  'освободить': defaultdict(int, {'neutral': 1}),
#  'реагировать': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'дебаты': defaultdict(int, {'negative': 1}),
#  'роль': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'Германия': defaultdict(int, {'negative': 2}),
#  'жить': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'строить': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'территория': defaultdict(int, {'negative': 2}),
#  'рука': defaultdict(int, {'negative': 2}),
#  'тварь': defaultdict(int, {'positive': 5}),
#  'снять': defaultdict(int, {'negative': 5, 'neutral': 5, 'positive': 3}),
#  'форма': defaultdict(int, {'neutral': 1, 'negative': 2}),
#  'идея': defaultdict(int, {'positive': 2}),
#  'друг': defaultdict(int, {'positive': 5, 'negative': 1}),
#  'вольнодумец': defaultdict(int, {'negative': 1}),
#  'преподаватель': defaultdict(int, {'positive': 1}),
#  'пара': defaultdict(int, {'positive': 2}),
#  'поклонник': defaultdict(int, {'negative': 1}),
#  'ориентация': defaultdict(int, {'positive/negative': 1}),
#  'раскрывать': defaultdict(int, {'positive': 2}),
#  'представитель': defaultdict(int, {'neutral': 1}),
#  'спин-офф': defaultdict(int, {'negative': 1}),
#  'дереть': defaultdict(int, {'positive': 1}),
#  'служба': defaultdict(int, {'positive': 3}),
#  'вынудить': defaultdict(int, {'negative': 1}),
#  'скончаться': defaultdict(int, {'negative': 2}),
#  'произойти': defaultdict(int,
#              {'negative': 22, 'neutral': 3, 'positive/negative': 1}),
#  'состав': defaultdict(int, {'neutral': 2, 'positive': 1}),
#  'констатировать': defaultdict(int, {'negative': 2}),
#  'обстоятельство': defaultdict(int, {'negative': 3}),
#  'госпитализировать': defaultdict(int, {'negative': 4}),
#  'покушение': defaultdict(int, {'negative': 6}),
#  'автомобиль': defaultdict(int, {'neutral': 1}),
#  'Александр': defaultdict(int, {'positive': 1}),
#  'сесть': defaultdict(int, {'neutral': 1}),
#  'освещение': defaultdict(int, {'negative': 1}),
#  'есть': defaultdict(int, {'neutral': 1}),
#  'переход': defaultdict(int, {'positive': 1}),
#  'Хенсен': defaultdict(int, {'positive': 1}),
#  'отрезать': defaultdict(int, {'negative': 1}),
#  'решение': defaultdict(int, {'positive': 6, 'neutral': 3, 'negative': 2}),
#  'подтверждать': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'продолжаться': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'действие': defaultdict(int, {'positive': 3, 'negative': 4}),
#  'оправдать': defaultdict(int, {'positive': 1}),
#  'быть': defaultdict(int,
#              {'neutral': 2,
#               'positive': 4,
#               'negative': 7,
#               'positive/negative': 2}),
#  'сталкиваться': defaultdict(int, {'negative': 2}),
#  'борьба': defaultdict(int,
#              {'positive/negative': 1,
#               'negative': 11,
#               'positive': 4,
#               'neutral': 2}),
#  'проявление': defaultdict(int, {'negative': 3}),
#  'виноватый': defaultdict(int, {'negative': 1}),
#  'одержать': defaultdict(int, {'positive': 8}),
#  'записка': defaultdict(int, {'negative': 3}),
#  'знакомство': defaultdict(int, {'negative': 1}),
#  'тянуться': defaultdict(int, {'negative': 1}),
#  'заразить': defaultdict(int, {'negative': 1}),
#  'причастность': defaultdict(int,
#              {'negative': 2, 'neutral': 1, 'positive': 1}),
#  'заражение': defaultdict(int, {'negative': 1}),
#  'актер': defaultdict(int, {'positive': 1}),
#  'маска': defaultdict(int, {'neutral': 1}),
#  'тупой': defaultdict(int, {'neutral': 1}),
#  'разум': defaultdict(int, {'positive': 1}),
#  'станция': defaultdict(int, {'positive': 1}),
#  'грозить': defaultdict(int, {'negative': 10}),
#  'непосредственность': defaultdict(int, {'positive': 1}),
#  'исчезнуть': defaultdict(int, {'positive': 1}),
#  'простота': defaultdict(int, {'positive': 1}),
#  'свобода': defaultdict(int, {'positive': 2}),
#  'закон': defaultdict(int, {'positive': 3, 'negative': 7}),
#  'обладать': defaultdict(int, {'negative': 1}),
#  'утверждение': defaultdict(int, {'negative': 1}),
#  'поляк': defaultdict(int, {'negative': 1}),
#  'память': defaultdict(int, {'neutral': 3, 'positive': 1}),
#  'лицо': defaultdict(int, {'negative': 2, 'positive': 4}),
#  'получение': defaultdict(int, {'positive/negative': 2, 'positive': 1}),
#  'начаться': defaultdict(int, {'negative': 7, 'positive/negative': 1}),
#  'ухудшение': defaultdict(int, {'positive/negative': 1}),
#  'больница': defaultdict(int, {'negative': 1}),
#  'кировлесаобвиняемый': defaultdict(int, {'positive/negative': 1}),
#  'режим': defaultdict(int, {'positive': 2, 'negative': 2, 'neutral': 1}),
#  'отправить': defaultdict(int, {'negative': 5}),
#  'гимн': defaultdict(int, {'positive': 1}),
#  'заменить': defaultdict(int, {'positive': 1, 'neutral': 1, 'negative': 1}),
#  'сенатор': defaultdict(int, {'positive': 1}),
#  'значение': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'атрибут': defaultdict(int, {'positive': 1}),
#  'дать': defaultdict(int, {'neutral': 4, 'positive': 2, 'negative': 3}),
#  'называть': defaultdict(int, {'negative': 3, 'positive': 3}),
#  'пресечь': defaultdict(int, {'negative': 2}),
#  'переправить': defaultdict(int, {'neutral': 1}),
#  'документ': defaultdict(int, {'negative': 1}),
#  'сделка': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'html': defaultdict(int, {'neutral': 1}),
#  'изумление': defaultdict(int, {'positive': 3}),
#  'моды00': defaultdict(int, {'positive': 1}),
#  'утопать': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'ликвидировать': defaultdict(int, {'neutral': 1}),
#  'формироваться': defaultdict(int, {'negative': 1}),
#  'усмотреть': defaultdict(int, {'negative': 1}),
#  'влияние': defaultdict(int, {'positive': 2}),
#  'вернуть': defaultdict(int, {'positive': 16}),
#  'следствие': defaultdict(int, {'negative': 1}),
#  'нести': defaultdict(int, {'negative': 1, 'positive': 3}),
#  'теория': defaultdict(int, {'positive': 2}),
#  'период': defaultdict(int, {'neutral': 1, 'negative': 2}),
#  'темный': defaultdict(int, {'neutral': 1}),
#  'крыша': defaultdict(int, {'positive': 1}),
#  'с': defaultdict(int, {'positive': 20}),
#  'торчать': defaultdict(int, {'negative': 1}),
#  'утолить': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'ликвидация': defaultdict(int, {'negative': 1}),
#  'разговор': defaultdict(int, {'positive': 2, 'negative': 1, 'neutral': 1}),
#  'необъективный': defaultdict(int, {'negative': 1}),
#  'призывать': defaultdict(int, {'positive': 2}),
#  'помнить': defaultdict(int, {'positive': 1}),
#  'устанавливать': defaultdict(int, {'positive': 2}),
#  'сотрудничать': defaultdict(int, {'negative': 1}),
#  'штраф': defaultdict(int, {'negative': 4, 'neutral': 1}),
#  'армия': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'УПА': defaultdict(int, {'negative': 2}),
#  'участник': defaultdict(int, {'negative': 1}),
#  'организовывать': defaultdict(int,
#              {'positive': 2, 'negative': 3, 'neutral': 1}),
#  'Организация': defaultdict(int, {'negative': 2}),
#  'националист': defaultdict(int, {'negative': 1}),
#  'оценка': defaultdict(int, {'neutral': 2}),
#  'жертва': defaultdict(int, {'negative': 4}),
#  'защитить': defaultdict(int, {'positive': 1}),
#  'регулирование': defaultdict(int, {'negative': 1}),
#  'стоить': defaultdict(int, {'negative': 5, 'positive': 2}),
#  'привязать': defaultdict(int, {'negative': 1}),
#  'прогноз': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'процент': defaultdict(int, {'positive': 1}),
#  'лишиться': defaultdict(int, {'positive/negative': 1}),
#  'сеанс': defaultdict(int, {'positive': 1}),
#  'поесть': defaultdict(int, {'positive/negative': 1}),
#  'пытать': defaultdict(int, {'negative': 1}),
#  'убивать': defaultdict(int,
#              {'positive': 1, 'negative': 1, 'positive/negative': 1}),
#  'любовь': defaultdict(int, {'positive': 1}),
#  'геймер': defaultdict(int, {'negative': 1}),
#  'неизвестный': defaultdict(int, {'positive': 1}),
#  'бороться': defaultdict(int, {'neutral': 1, 'negative': 4}),
#  'ввести': defaultdict(int,
#              {'negative': 3, 'neutral': 2, 'positive/negative': 5}),
#  'использование': defaultdict(int, {'negative': 2}),
#  'лечение': defaultdict(int, {'neutral': 1, 'negative': 3}),
#  'зависимость': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'работа': defaultdict(int, {'positive': 4, 'negative': 5}),
#  'окончание': defaultdict(int, {'negative': 1}),
#  'договор': defaultdict(int, {'positive': 1}),
#  'надеяться': defaultdict(int, {'negative': 1}),
#  'повышение': defaultdict(int, {'positive': 3}),
#  'осведомленность': defaultdict(int, {'negative': 1}),
#  'оценивать': defaultdict(int, {'positive': 3, 'negative': 1, 'neutral': 1}),
#  'спасти': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'спать': defaultdict(int, {'neutral': 1}),
#  'будить': defaultdict(int, {'neutral': 1}),
#  'доставить': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'поток': defaultdict(int, {'positive': 7}),
#  'выделить': defaultdict(int, {'positive': 1}),
#  'прибыль': defaultdict(int, {'positive': 1}),
#  'сохранить': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'сходить': defaultdict(int, {'negative': 2}),
#  'политика': defaultdict(int, {'negative': 1, 'neutral': 2}),
#  'говорить': defaultdict(int,
#              {'positive/negative': 1, 'negative': 1, 'positive': 1}),
#  'очевидный': defaultdict(int, {'positive': 1}),
#  'нагрузка': defaultdict(int, {'negative': 1}),
#  'сокращать': defaultdict(int, {'neutral': 1}),
#  'попасть': defaultdict(int,
#              {'negative': 9, 'neutral': 3, 'positive/negative': 1}),
#  'Рейчел': defaultdict(int, {'negative': 1}),
#  'засыпать': defaultdict(int, {'positive/negative': 1}),
#  'яма': defaultdict(int, {'positive': 2}),
#  'новость': defaultdict(int, {'positive': 16, 'negative': 1}),
#  'чувство': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'отметить': defaultdict(int, {'negative': 3, 'neutral': 1, 'positive': 3}),
#  'сомневаться': defaultdict(int, {'positive': 1}),
#  'спортсмен': defaultdict(int, {'positive': 10, 'negative': 3}),
#  'оставлять': defaultdict(int, {'positive': 1}),
#  'поддержка': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'подвергнуться': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'рэпер': defaultdict(int, {'positive': 1}),
#  'разорвать': defaultdict(int, {'negative': 2}),
#  'принимать': defaultdict(int, {'positive': 8, 'neutral': 1, 'negative': 1}),
#  'Шакур': defaultdict(int, {'positive': 1}),
#  'культ': defaultdict(int, {'positive': 2}),
#  'бог': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'царица': defaultdict(int, {'positive': 2}),
#  'славиться': defaultdict(int, {'positive': 1}),
#  'вырасти': defaultdict(int, {'positive': 1}),
#  'найти': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'бренд': defaultdict(int, {'positive': 4}),
#  'разведка': defaultdict(int, {'neutral': 2}),
#  'трактовать': defaultdict(int, {'positive': 1}),
#  'требовать': defaultdict(int, {'positive': 1}),
#  'скандал': defaultdict(int, {'positive/negative': 1}),
#  'вмешательство': defaultdict(int, {'negative': 1}),
#  'убедиться': defaultdict(int, {'positive': 2}),
#  'преследование': defaultdict(int, {'negative': 1}),
#  'наколкамиЗакон': defaultdict(int, {'positive': 1}),
#  'хороший': defaultdict(int, {'negative': 1}),
#  'проявиться': defaultdict(int, {'neutral': 1}),
#  'группа': defaultdict(int, {'negative': 3, 'neutral': 1, 'positive': 2}),
#  'повышать': defaultdict(int, {'negative': 2}),
#  'попадание': defaultdict(int, {'negative': 1}),
#  'Королевство': defaultdict(int, {'negative': 1}),
#  'существовать': defaultdict(int, {'negative': 5}),
#  'стандартный': defaultdict(int, {'positive/negative': 1, 'positive': 2}),
#  'перехватить': defaultdict(int, {'negative': 1}),
#  'истребитель': defaultdict(int, {'positive/negative': 1}),
#  'перерастать': defaultdict(int,
#              {'positive/negative': 2, 'negative': 1, 'neutral': 1}),
#  'войнуОб': defaultdict(int, {'neutral': 1}),
#  'контакт': defaultdict(int, {'positive': 2}),
#  'обвинять': defaultdict(int, {'negative': 4}),
#  'поддерживать': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'наряду': defaultdict(int, {'positive': 1}),
#  'демократия': defaultdict(int, {'positive': 1}),
#  'ничто': defaultdict(int, {'negative': 1}),
#  'признание': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'предложить': defaultdict(int, {'neutral': 1}),
#  'обращать': defaultdict(int, {'positive': 2}),
#  'традиция': defaultdict(int, {'neutral': 1}),
#  'подвергать': defaultdict(int, {'negative': 1}),
#  'создать': defaultdict(int, {'neutral': 1, 'negative': 1, 'positive': 1}),
#  'предложение': defaultdict(int, {'positive': 1}),
#  'прогнозировать': defaultdict(int, {'positive': 1}),
#  'ждать': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'догнать': defaultdict(int, {'positive': 1}),
#  'удерживать': defaultdict(int, {'negative': 1}),
#  'литература': defaultdict(int, {'positive': 4, 'neutral': 2}),
#  'наталкиваться': defaultdict(int, {'negative': 1}),
#  '2017гомы': defaultdict(int, {'negative': 2}),
#  'книга': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'слава': defaultdict(int, {'positive': 1}),
#  'служить': defaultdict(int, {'positive': 1}),
#  'испытывать': defaultdict(int, {'negative': 1}),
#  'требование': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'руководитель': defaultdict(int, {'positive': 1}),
#  'поступка': defaultdict(int, {'negative': 1}),
#  'лежать': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'устроить': defaultdict(int, {'negative': 8}),
#  'тот': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'школе00': defaultdict(int, {'positive': 1}),
#  'заслуживать': defaultdict(int, {'negative': 2}),
#  'желание': defaultdict(int, {'negative': 2}),
#  'выглядеть': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'семья': defaultdict(int, {'positive': 1, 'negative': 1, 'neutral': 1}),
#  'резня': defaultdict(int, {'negative': 2}),
#  'подозрение': defaultdict(int, {'negative': 2, 'neutral': 1, 'positive': 1}),
#  'энергия': defaultdict(int, {'neutral': 9}),
#  'материя': defaultdict(int, {'neutral': 9, 'positive': 1}),
#  'ВселеннаяМир': defaultdict(int, {'positive/negative': 1}),
#  'канал': defaultdict(int, {'negative': 1, 'positive': 1, 'neutral': 1}),
#  'подразумевать': defaultdict(int, {'negative': 2}),
#  'распадаться': defaultdict(int, {'positive': 1}),
#  'излучение': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'безмассовый': defaultdict(int, {'positive': 1}),
#  'позволять': defaultdict(int, {'positive': 2, 'negative': 7, 'neutral': 1}),
#  'происходить': defaultdict(int, {'negative': 1, 'positive/negative': 1}),
#  'параметр': defaultdict(int, {'neutral': 1}),
#  'галактика': defaultdict(int, {'neutral': 1}),
#  'вина': defaultdict(int, {'negative': 1}),
#  'житель': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'корзина': defaultdict(int, {'negative': 1}),
#  'распространять': defaultdict(int, {'negative': 3}),
#  'приобретать': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'Азияточема': defaultdict(int, {'neutral': 1}),
#  'эпоха': defaultdict(int, {'positive': 1}),
#  'прийтись': defaultdict(int,
#              {'positive': 1, 'negative': 3, 'positive/negative': 1}),
#  'занимать': defaultdict(int, {'positive': 1}),
#  'смысл': defaultdict(int, {'positive': 2}),
#  'смерть': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'литр': defaultdict(int, {'positive': 1}),
#  'газ': defaultdict(int, {'positive': 1}),
#  'отменить': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'идти': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'оправдание': defaultdict(int, {'neutral': 1}),
#  'добиваться': defaultdict(int, {'positive': 1}),
#  'конец': defaultdict(int, {'positive': 1}),
#  'что-то': defaultdict(int, {'negative': 2}),
#  'изучить': defaultdict(int, {'positive': 1}),
#  'оценить': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'отдых': defaultdict(int, {'positive': 2}),
#  'основать': defaultdict(int, {'positive': 1}),
#  'заключение': defaultdict(int, {'negative': 5}),
#  'обрезание': defaultdict(int, {'negative': 1}),
#  'фактор': defaultdict(int, {'positive': 2}),
#  'подход': defaultdict(int, {'negative': 1}),
#  'характер': defaultdict(int, {'positive/negative': 2, 'negative': 1}),
#  'поведение': defaultdict(int, {'negative': 1}),
#  'госпожь': defaultdict(int, {'negative': 1}),
#  'знак': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'насилие': defaultdict(int, {'positive/negative': 2}),
#  'харассмент': defaultdict(int, {'negative': 1}),
#  'оправдаться': defaultdict(int, {'neutral': 1}),
#  'слово': defaultdict(int, {'positive': 1}),
#  'источник': defaultdict(int, {'positive': 2, 'neutral': 2, 'negative': 2}),
#  'заверить': defaultdict(int, {'positive': 1}),
#  'намерен': defaultdict(int, {'negative': 1}),
#  'ограничение': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'отсутствие': defaultdict(int, {'negative': 4, 'positive': 2}),
#  'снегопад': defaultdict(int, {'positive': 2}),
#  'выявить': defaultdict(int, {'negative': 2, 'neutral': 1}),
#  'ЖКХ': defaultdict(int, {'positive': 1}),
#  'надвигаться': defaultdict(int, {'negative': 1}),
#  'отказ': defaultdict(int, {'neutral': 1}),
#  'показать': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'группировка': defaultdict(int, {'negative': 8}),
#  'обучать': defaultdict(int, {'negative': 1}),
#  'фанатик': defaultdict(int, {'positive': 1}),
#  'превращать': defaultdict(int, {'negative': 1}),
#  'курс': defaultdict(int, {'positive': 1}),
#  'сторона': defaultdict(int, {'negative': 3, 'positive': 1, 'neutral': 1}),
#  'забирать': defaultdict(int, {'positive': 1}),
#  'сдавать': defaultdict(int, {'negative': 3}),
#  'экстремист': defaultdict(int, {'negative': 1}),
#  'изготовлять': defaultdict(int, {'negative': 1}),
#  'обмен': defaultdict(int, {'negative': 1}),
#  'правило': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'хотеть': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'депрессия': defaultdict(int, {'positive': 2}),
#  'ответить': defaultdict(int, {'positive': 2}),
#  'прекратиться': defaultdict(int, {'negative': 1}),
#  'готовность': defaultdict(int, {'positive': 1}),
#  'можно': defaultdict(int, {'positive': 1}),
#  'выражать': defaultdict(int, {'positive': 2}),
#  'осознать': defaultdict(int, {'negative': 1}),
#  'решить': defaultdict(int, {'neutral': 2, 'positive': 2, 'negative': 1}),
#  'пост': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'женщина': defaultdict(int, {'positive': 1, 'negative': 4}),
#  'остаться': defaultdict(int, {'positive': 2, 'negative': 4, 'neutral': 1}),
#  'спасение': defaultdict(int, {'negative': 1}),
#  'соблюдаться': defaultdict(int, {'negative': 1}),
#  'торговец': defaultdict(int, {'negative': 1}),
#  'толкнуть': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'приговорить': defaultdict(int, {'neutral': 4, 'positive': 1, 'negative': 3}),
#  'выйти': defaultdict(int, {'negative': 1}),
#  'узнать': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'вещество': defaultdict(int, {'negative': 7, 'neutral': 1}),
#  'одержимый': defaultdict(int, {'positive': 1}),
#  'продажа': defaultdict(int, {'negative': 3}),
#  'задыхаться': defaultdict(int, {'positive': 1}),
#  'контракт': defaultdict(int, {'positive': 2}),
#  'держава': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'другой': defaultdict(int, {'positive': 1}),
#  'добавить': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'проходить': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'удивить': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'компоновка': defaultdict(int, {'positive': 1}),
#  'голубой': defaultdict(int, {'neutral': 1}),
#  'мероприятие': defaultdict(int, {'positive': 3}),
#  'подросток': defaultdict(int, {'negative': 1}),
#  'облегчить': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'амортизация': defaultdict(int, {'positive': 1}),
#  'дорога': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'название': defaultdict(int, {'positive': 3, 'neutral': 1}),
#  'автомобильный': defaultdict(int, {'positive': 1}),
#  'имиджборд': defaultdict(int, {'positive': 1}),
#  'герой': defaultdict(int, {'positive/negative': 1, 'positive': 1}),
#  '2017Сдулсе': defaultdict(int, {'positive/negative': 1}),
#  'содержаться': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'инъекция': defaultdict(int, {'positive': 1}),
#  'съемка': defaultdict(int, {'negative': 1}),
#  'следовать': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'видный': defaultdict(int, {'negative': 1}),
#  'пункт': defaultdict(int, {'negative': 1}),
#  'иметь': defaultdict(int, {'positive': 3, 'neutral': 1, 'negative': 1}),
#  'отзыв': defaultdict(int, {'neutral': 1}),
#  'качество': defaultdict(int, {'negative': 2, 'positive': 1, 'neutral': 2}),
#  'противодействие': defaultdict(int,
#              {'neutral': 3, 'positive/negative': 1, 'negative': 2}),
#  'противник': defaultdict(int, {'positive/negative': 1}),
#  'наложить': defaultdict(int, {'negative': 2}),
#  'волна': defaultdict(int,
#              {'neutral': 1,
#               'positive/negative': 1,
#               'negative': 1,
#               'positive': 1}),
#  'воспринимать': defaultdict(int, {'positive': 1}),
#  'феминизм': defaultdict(int, {'positive': 2}),
#  'искусство': defaultdict(int, {'positive': 1}),
#  'сочетать': defaultdict(int, {'positive': 1}),
#  'провозглашать': defaultdict(int, {'positive': 1}),
#  'соображение': defaultdict(int, {'positive': 1}),
#  'опухоль': defaultdict(int, {'neutral': 1, 'negative': 4}),
#  'удалить': defaultdict(int, {'negative': 1}),
#  'откладывать': defaultdict(int, {'neutral': 1}),
#  'весить': defaultdict(int, {'negative': 1}),
#  'проверять': defaultdict(int, {'negative': 1}),
#  'критик': defaultdict(int, {'negative': 1}),
#  'мясо': defaultdict(int, {'positive/negative': 1, 'neutral': 2}),
#  'много': defaultdict(int, {'negative': 1}),
#  'они': defaultdict(int, {'neutral': 1}),
#  '90-еЧто': defaultdict(int, {'positive': 1}),
#  'путевка': defaultdict(int, {'positive': 1}),
#  'комментарий': defaultdict(int, {'neutral': 3, 'negative': 1}),
#  'порохобот': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'возразить': defaultdict(int, {'positive': 1}),
#  'охранять': defaultdict(int, {'positive': 1}),
#  'симулятор': defaultdict(int, {'positive': 1}),
#  'степень': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'такой': defaultdict(int, {'neutral': 1, 'negative': 2}),
#  'исследовать': defaultdict(int, {'neutral': 1}),
#  'галактик': defaultdict(int, {'neutral': 1}),
#  'тир': defaultdict(int, {'positive': 1}),
#  'вложение': defaultdict(int, {'positive': 1}),
#  'клиент': defaultdict(int, {'positive': 1}),
#  'он': defaultdict(int, {'negative': 1}),
#  'клуб': defaultdict(int, {'positive': 1}),
#  'студент': defaultdict(int, {'negative': 1}),
#  'подтолкнуть': defaultdict(int, {'negative': 1}),
#  '***': defaultdict(int, {'negative': 1}),
#  'собрать': defaultdict(int, {'neutral': 1}),
#  'флешмоб': defaultdict(int, {'positive': 1}),
#  'рассказывать': defaultdict(int, {'negative': 3, 'positive/negative': 1}),
#  'врач': defaultdict(int, {'negative': 1}),
#  'благодарить': defaultdict(int, {'positive': 1}),
#  'пересмотреть': defaultdict(int, {'negative': 1}),
#  'вывод': defaultdict(int, {'negative': 3}),
#  'противоречить': defaultdict(int, {'positive': 1}),
#  'вред': defaultdict(int, {'positive': 1}),
#  'компенсация': defaultdict(int, {'negative': 1}),
#  'процедура': defaultdict(int, {'negative': 1}),
#  'ряд': defaultdict(int, {'negative': 2}),
#  'болезнь': defaultdict(int, {'negative': 1}),
#  'миелофиброз': defaultdict(int, {'negative': 1}),
#  'онкология': defaultdict(int, {'negative': 1}),
#  'относиться': defaultdict(int, {'positive': 1}),
#  'точный': defaultdict(int, {'neutral': 1}),
#  'точка': defaultdict(int, {'positive': 1, 'negative': 1, 'neutral': 1}),
#  'заниматься': defaultdict(int, {'negative': 4}),
#  'забраться': defaultdict(int, {'negative': 1}),
#  'зоопаркСпасатель': defaultdict(int, {'positive': 1}),
#  'потрудиться': defaultdict(int, {'negative': 1}),
#  'спасать': defaultdict(int, {'neutral': 1}),
#  'игра': defaultdict(int, {'positive': 3}),
#  'посетить': defaultdict(int, {'positive': 1}),
#  'свежий': defaultdict(int, {'positive': 1}),
#  'ремонт': defaultdict(int, {'positive': 5}),
#  'реконструкция': defaultdict(int, {'positive': 1}),
#  'средства': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'утверждать': defaultdict(int, {'positive': 3, 'negative': 2}),
#  'россиянин': defaultdict(int, {'positive': 2}),
#  'продюсер': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'расположить': defaultdict(int, {'positive': 1}),
#  'журнал': defaultdict(int, {'positive': 1}),
#  'искренний': defaultdict(int, {'positive/negative': 1, 'positive': 1}),
#  'разговаривать': defaultdict(int, {'negative': 1}),
#  'удивляться': defaultdict(int, {'negative': 1}),
#  'падение': defaultdict(int, {'positive': 1}),
#  'Запад': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'рассуждать': defaultdict(int, {'negative': 1}),
#  'риск': defaultdict(int, {'negative': 3, 'neutral': 1}),
#  'растерять': defaultdict(int, {'positive': 1}),
#  'корень': defaultdict(int, {'positive': 1}),
#  'осуществление': defaultdict(int, {'neutral': 1}),
#  'связывать': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'превратиться': defaultdict(int, {'negative': 1}),
#  'надежда': defaultdict(int, {'positive': 1}),
#  'исполнение': defaultdict(int, {'negative': 1}),
#  'ук': defaultdict(int, {'negative': 1}),
#  'статья': defaultdict(int, {'negative': 8}),
#  'производство': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'строительство': defaultdict(int, {'negative': 1}),
#  'тюрьма': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'тишинуОхранник': defaultdict(int, {'negative': 1}),
#  'арестант': defaultdict(int, {'positive': 1}),
#  'отбывать': defaultdict(int, {'negative': 2}),
#  'руководить': defaultdict(int, {'negative': 1}),
#  'соучастник': defaultdict(int, {'negative': 1}),
#  'обувь': defaultdict(int, {'negative': 1}),
#  'нанести': defaultdict(int, {'negative': 6}),
#  'цена': defaultdict(int, {'negative': 2, 'neutral': 1}),
#  'Радио': defaultdict(int, {'positive': 1}),
#  'ухищрение': defaultdict(int, {'neutral': 1}),
#  'удаться': defaultdict(int, {'positive': 2}),
#  'калибр': defaultdict(int, {'neutral': 1}),
#  'девочка': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'имплант': defaultdict(int, {'positive': 1}),
#  'маленький': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'аниме-девочка': defaultdict(int, {'neutral': 1}),
#  'повторять': defaultdict(int, {'positive': 1}),
#  'продолжить': defaultdict(int, {'negative': 2}),
#  'попытка': defaultdict(int, {'negative': 4}),
#  'фальсифицировать': defaultdict(int, {'positive': 1}),
#  'обелять': defaultdict(int, {'negative': 1}),
#  'воин': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'вирус': defaultdict(int, {'negative': 1}),
#  'иммунитет': defaultdict(int, {'negative': 1}),
#  'беспокойство': defaultdict(int, {'positive': 1}),
#  'расправить': defaultdict(int, {'negative': 1}),
#  'неонацист': defaultdict(int, {'neutral': 1}),
#  '75-летие': defaultdict(int, {'positive': 1}),
#  'линия': defaultdict(int, {'negative': 1}),
#  'положить': defaultdict(int, {'positive': 1}),
#  'война': defaultdict(int, {'positive': 6, 'negative': 2}),
#  'перелом': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'день': defaultdict(int, {'negative': 2, 'neutral': 1}),
#  'войска': defaultdict(int, {'negative': 1}),
#  'сражение': defaultdict(int, {'negative': 1}),
#  'череда': defaultdict(int, {'positive/negative': 1}),
#  'переломный': defaultdict(int, {'negative': 1}),
#  'телепрограмма': defaultdict(int, {'negative': 1}),
#  'эфир': defaultdict(int, {'positive': 5, 'negative': 1}),
#  'хирург': defaultdict(int, {'neutral': 1}),
#  'стоимость': defaultdict(int, {'neutral': 2, 'positive': 1}),
#  'центр': defaultdict(int, {'positive': 2}),
#  'освобождение': defaultdict(int, {'negative': 2}),
#  'динамика': defaultdict(int, {'positive': 1}),
#  'суд': defaultdict(int, {'positive': 3}),
#  'восторжествовать': defaultdict(int, {'positive': 1}),
#  'иностранец': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'поляхКто': defaultdict(int, {'positive': 1}),
#  'узза': defaultdict(int, {'positive': 1}),
#  'линейка': defaultdict(int, {'neutral': 1}),
#  'перелезти': defaultdict(int, {'positive': 1}),
#  'произведение': defaultdict(int, {'positive': 2}),
#  'художник': defaultdict(int, {'positive': 1}),
#  'прозвать': defaultdict(int, {'neutral': 1}),
#  'отрицать': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'узнавать': defaultdict(int, {'negative': 1}),
#  'Толстой': defaultdict(int, {'negative': 1}),
#  'осудить': defaultdict(int, {'negative': 1}),
#  'колледж': defaultdict(int, {'positive': 1}),
#  'смущать': defaultdict(int, {'positive': 1}),
#  'вод': defaultdict(int, {'negative': 1}),
#  'разработать': defaultdict(int, {'positive': 1}),
#  'пистолет': defaultdict(int, {'neutral': 3}),
#  'детектив': defaultdict(int, {'positive': 1}),
#  'ограбление': defaultdict(int, {'negative': 2}),
#  'вторжение': defaultdict(int, {'negative': 1}),
#  'наркотик': defaultdict(int, {'negative': 1}),
#  'взрыв': defaultdict(int, {'positive': 1}),
#  'раздаться': defaultdict(int, {'positive/negative': 1}),
#  'здание': defaultdict(int, {'neutral': 1}),
#  'строение': defaultdict(int, {'positive/negative': 1}),
#  'запчасть': defaultdict(int, {'positive/negative': 1}),
#  'освещать': defaultdict(int, {'negative': 1}),
#  'обстрелять': defaultdict(int,
#              {'negative': 1, 'positive': 1, 'positive/negative': 1}),
#  'уточнять': defaultdict(int, {'negative': 2}),
#  'засекретить': defaultdict(int, {'negative': 1}),
#  'означать': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'расширение': defaultdict(int, {'positive/negative': 1}),
#  'крик': defaultdict(int, {'positive': 1}),
#  'половина': defaultdict(int, {'positive': 1}),
#  'школьница': defaultdict(int, {'negative': 1}),
#  'жаловаться': defaultdict(int, {'negative': 2}),
#  'внедорожник': defaultdict(int, {'positive': 1}),
#  'безработный': defaultdict(int, {'positive': 1}),
#  'изъять': defaultdict(int, {'positive': 1}),
#  'орудие': defaultdict(int, {'negative': 2}),
#  'микротия': defaultdict(int, {'negative': 1}),
#  'ухо': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'раковина': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'внедряться': defaultdict(int, {'negative': 1}),
#  'эффективный': defaultdict(int, {'negative': 1}),
#  'пририсовать': defaultdict(int, {'positive': 2}),
#  'нормальный': defaultdict(int, {'positive': 1}),
#  'мысль': defaultdict(int, {'negative': 1}),
#  'программа': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'вопрос': defaultdict(int, {'positive': 7}),
#  'блок': defaultdict(int, {'positive': 1, 'positive/negative': 1}),
#  'круг': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'сессия': defaultdict(int, {'positive': 1}),
#  'посвятить': defaultdict(int, {'positive': 2}),
#  'деньги': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'формирование': defaultdict(int, {'negative': 1}),
#  'врезка': defaultdict(int, {'negative': 1}),
#  'сообщать': defaultdict(int, {'negative': 4, 'positive': 2}),
#  'назначить': defaultdict(int, {'negative': 3}),
#  'слушать': defaultdict(int, {'negative': 1}),
#  'самочувствие': defaultdict(int, {'negative': 1}),
#  'вымогательство': defaultdict(int, {'positive/negative': 1}),
#  'направить': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'цель': defaultdict(int, {'negative': 1, 'positive': 1, 'neutral': 1}),
#  'задержание': defaultdict(int, {'negative': 2}),
#  'возмещать': defaultdict(int, {'negative': 1}),
#  'терять': defaultdict(int,
#              {'positive': 1, 'positive/negative': 1, 'negative': 1}),
#  'мешать': defaultdict(int, {'positive': 1}),
#  'основание': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'отмена': defaultdict(int, {'negative': 2}),
#  'дисквалификация': defaultdict(int, {'negative': 1}),
#  'спорт': defaultdict(int, {'positive': 2}),
#  'все': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'целостность': defaultdict(int, {'neutral': 1}),
#  'покрыть': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'забота': defaultdict(int, {'positive': 1}),
#  'предшественник': defaultdict(int, {'positive': 1}),
#  'оставаться': defaultdict(int, {'neutral': 2, 'negative': 3, 'positive': 1}),
#  'угроза': defaultdict(int, {'positive': 4, 'negative': 1}),
#  'ставить': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'возможность': defaultdict(int, {'positive': 2}),
#  'обстановка': defaultdict(int, {'positive': 2}),
#  'взвешивать': defaultdict(int, {'negative': 1}),
#  'спецслужба': defaultdict(int, {'negative': 1}),
#  'летчик': defaultdict(int, {'negative': 2}),
#  'метод': defaultdict(int, {'neutral': 1, 'negative': 1, 'positive': 1}),
#  'склонить': defaultdict(int, {'negative': 1}),
#  'надуманность': defaultdict(int, {'neutral': 1}),
#  'срок': defaultdict(int, {'neutral': 1, 'negative': 3}),
#  'наличие': defaultdict(int, {'positive/negative': 1, 'negative': 1}),
#  'композиция': defaultdict(int, {'positive': 1}),
#  'базироваться': defaultdict(int, {'positive': 1}),
#  'аромат': defaultdict(int, {'positive': 1}),
#  'соблазнять': defaultdict(int, {'positive': 1}),
#  'заключить': defaultdict(int, {'positive': 1}),
#  'стекло': defaultdict(int, {'neutral': 1}),
#  'дозаправка': defaultdict(int, {'positive': 1}),
#  'направление': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'открыть': defaultdict(int, {'positive': 1}),
#  'включая': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'субсидирование': defaultdict(int, {'positive': 1}),
#  'расход': defaultdict(int, {'positive': 1}),
#  'gif-сервис': defaultdict(int, {'positive': 1}),
#  'инструмент': defaultdict(int, {'positive': 2}),
#  'генерирование': defaultdict(int, {'positive': 1}),
#  'обратиться': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'последующий': defaultdict(int, {'negative': 1}),
#  'предрекнуть': defaultdict(int, {'neutral': 1}),
#  'провоцировать': defaultdict(int, {'neutral': 2}),
#  'ослабление': defaultdict(int, {'positive/negative': 1}),
#  'организм': defaultdict(int, {'positive': 1}),
#  'внести': defaultdict(int, {'negative': 1}),
#  'нет': defaultdict(int, {'negative': 3, 'positive': 2, 'neutral': 2}),
#  'бизнесмен': defaultdict(int, {'positive': 2}),
#  'благо': defaultdict(int, {'positive': 1}),
#  'честь': defaultdict(int, {'positive': 2}),
#  'уважение': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'верить': defaultdict(int, {'positive': 1}),
#  'нация': defaultdict(int, {'positive/negative': 1}),
#  'уничтожать': defaultdict(int, {'positive': 1}),
#  'медаль': defaultdict(int, {'positive': 1}),
#  'плакать': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'подозревать': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'пособничество': defaultdict(int, {'negative': 3}),
#  'погибать': defaultdict(int, {'negative': 2}),
#  'перевод': defaultdict(int, {'positive': 1}),
#  'введение': defaultdict(int, {'positive/negative': 2, 'negative': 1}),
#  'подпадать': defaultdict(int, {'positive/negative': 1, 'negative': 1}),
#  'заставить': defaultdict(int,
#              {'positive/negative': 1, 'positive': 1, 'negative': 1}),
#  'подрыть': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'усилие': defaultdict(int, {'positive': 1}),
#  'ослабить': defaultdict(int, {'positive': 1}),
#  'орган': defaultdict(int, {'positive': 1}),
#  'предоставить': defaultdict(int, {'negative': 1}),
#  'ездить': defaultdict(int, {'positive/negative': 1}),
#  'быстрый': defaultdict(int, {'positive': 1}),
#  'потерять': defaultdict(int, {'negative': 1}),
#  'развивать': defaultdict(int, {'positive/negative': 1}),
#  'ситуация': defaultdict(int, {'positive': 1, 'negative': 2, 'neutral': 1}),
#  'возмутить': defaultdict(int, {'positive': 1}),
#  'соответствовать': defaultdict(int, {'positive': 1}),
#  'исследование': defaultdict(int, {'positive': 1, 'negative': 1}),
#  ...}

# %%
[(senti, vals) for senti,vals in sentiments.items() if vals['negative']>10], '\n----\n',\
[(senti, vals) for senti,vals in sentiments.items() if vals['positive']>10]
# Out:
# ([('выразить',
#    defaultdict(int, {'positive': 2, 'negative': 11, 'neutral': 1})),
#   (None,
#    defaultdict(int,
#                {'positive': 157,
#                 'negative': 162,
#                 'neutral': 29,
#                 'positive/negative': 14})),
#   ('получить',
#    defaultdict(int, {'negative': 16, 'positive': 8, 'neutral': 3})),
#   ('стать', defaultdict(int, {'negative': 23, 'positive': 9, 'neutral': 5})),
#   ('признать',
#    defaultdict(int, {'negative': 23, 'positive': 5, 'neutral': 1})),
#   ('материал',
#    defaultdict(int, {'negative': 11, 'positive': 1, 'neutral': 2})),
#   ('обвинить', defaultdict(int, {'negative': 13, 'positive': 2})),
#   ('мочь',
#    defaultdict(int,
#                {'negative': 15,
#                 'positive': 11,
#                 'positive/negative': 2,
#                 'neutral': 1})),
#   ('ответственность',
#    defaultdict(int, {'negative': 11, 'positive/negative': 1, 'positive': 0})),
#   ('дело', defaultdict(int, {'negative': 30, 'neutral': 1, 'positive': 2})),
#   ('считать', defaultdict(int, {'negative': 13, 'positive': 2, 'neutral': 1})),
#   ('причина',
#    defaultdict(int,
#                {'neutral': 1,
#                 'negative': 12,
#                 'positive/negative': 1,
#                 'positive': 0})),
#   ('деятельность', defaultdict(int, {'negative': 13, 'positive': 2})),
#   ('год', defaultdict(int, {'neutral': 6, 'negative': 16, 'positive': 0})),
#   ('произойти',
#    defaultdict(int,
#                {'negative': 22,
#                 'neutral': 3,
#                 'positive/negative': 1,
#                 'positive': 0})),
#   ('борьба',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'negative': 11,
#                 'positive': 4,
#                 'neutral': 2}))],
#  '\n----\n',
#  [(None,
#    defaultdict(int,
#                {'positive': 157,
#                 'negative': 162,
#                 'neutral': 29,
#                 'positive/negative': 14})),
#   ('принять',
#    defaultdict(int, {'positive': 14, 'negative': 1, 'neutral': 10})),
#   ('обратить',
#    defaultdict(int, {'positive': 22, 'neutral': 1, 'negative': 0})),
#   ('мочь',
#    defaultdict(int,
#                {'negative': 15,
#                 'positive': 11,
#                 'positive/negative': 2,
#                 'neutral': 1})),
#   ('вернуть', defaultdict(int, {'positive': 16, 'negative': 0})),
#   ('с', defaultdict(int, {'positive': 20, 'negative': 0})),
#   ('новость', defaultdict(int, {'positive': 16, 'negative': 1}))])
